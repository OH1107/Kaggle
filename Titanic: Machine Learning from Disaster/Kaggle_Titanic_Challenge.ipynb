# %% [markdown]
# <a href="https://colab.research.google.com/github/OH1107/Kaggle/blob/main/Titanic%3A%20Machine%20Learning%20from%20Disaster/Kaggle_Titanic_Challenge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Titanic Challenge

# %% [markdown]
# ## Part 1 : 데이터 준비 및 모듈 임포트

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# 기본 데이터 정리 및 처리
import numpy as np
import pandas as pd

# 시각화
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
plt.style.use('seaborn-whitegrid')
import missingno

# 전처리 및 머신 러닝 알고리즘
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from xgboost import XGBClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import VotingClassifier

# 모델 튜닝 및 평가
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_predict
from sklearn import model_selection

# 경고 제거 (판다스가 에러 메세지를 자주 만들어 내기 때문에 이를 일단 무시하도록 설정)
import sys
import warnings

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### CSV to DF
# - csv를 임포트하여 데이터셋이 `pandas DataFrame`이 되도록 호출

# %%
test = pd.read_csv('/content/drive/My Drive/Colab Notebooks/독학_글로벌엑스퍼트/글로벌엑스퍼트-타이타닉-강의자료-학습도우미/titanic/test.csv')
train = pd.read_csv('/content/drive/My Drive/Colab Notebooks/독학_글로벌엑스퍼트/글로벌엑스퍼트-타이타닉-강의자료-학습도우미/titanic/train.csv')

# %% [markdown]
# ### 데이터프레임을 보는 다양한 방법

# %% [markdown]
# `head()` 첫 5행을 볼 수 있음

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
train.head(5)
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
train.head(n=5)
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
train.head(10)
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
# 5            6         0       3  ...   8.4583   NaN         Q
# 6            7         0       1  ...  51.8625   E46         S
# 7            8         0       3  ...  21.0750   NaN         S
# 8            9         1       3  ...  11.1333   NaN         S
# 9           10         1       2  ...  30.0708   NaN         C
#
# [10 rows x 12 columns]

# %%
train.head(3)
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
#
# [3 rows x 12 columns]

# %%
# head를 빼면 전부 축약되서 출력
train
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %% [markdown]
# `tail()` 마지막 5행을 볼 수 있음

# %%
train.tail()
# Out:
#      PassengerId  Survived  Pclass  ...   Fare Cabin  Embarked
# 886          887         0       2  ...  13.00   NaN         S
# 887          888         1       1  ...  30.00   B42         S
# 888          889         0       3  ...  23.45   NaN         S
# 889          890         1       1  ...  30.00  C148         C
# 890          891         0       3  ...   7.75   NaN         Q
#
# [5 rows x 12 columns]

# %%
train.tail(3)
# Out:
#      PassengerId  Survived  Pclass  ...   Fare Cabin  Embarked
# 888          889         0       3  ...  23.45   NaN         S
# 889          890         1       1  ...  30.00  C148         C
# 890          891         0       3  ...   7.75   NaN         Q
#
# [3 rows x 12 columns]

# %%
train.tail(10)
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 881          882         0       3  ...   7.8958   NaN         S
# 882          883         0       3  ...  10.5167   NaN         S
# 883          884         0       2  ...  10.5000   NaN         S
# 884          885         0       3  ...   7.0500   NaN         S
# 885          886         0       3  ...  29.1250   NaN         Q
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [10 rows x 12 columns]

# %% [markdown]
# `describe()` 각 열의 통계적인 면을 보여줌
#
# 기본은 연속된 값을 가진 열만 보여주나 `include='all'로 세팅하면 모두 볼 수 있음

# %%
train.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass  ...        Fare        Cabin  Embarked
# count    891.000000  891.000000  891.000000  ...  891.000000          204       889
# unique          NaN         NaN         NaN  ...         NaN          147         3
# top             NaN         NaN         NaN  ...         NaN  C23 C25 C27         S
# freq            NaN         NaN         NaN  ...         NaN            4       644
# mean     446.000000    0.383838    2.308642  ...   32.204208          NaN       NaN
# std      257.353842    0.486592    0.836071  ...   49.693429          NaN       NaN
# min        1.000000    0.000000    1.000000  ...    0.000000          NaN       NaN
# 25%      223.500000    0.000000    2.000000  ...    7.910400          NaN       NaN
# 50%      446.000000    0.000000    3.000000  ...   14.454200          NaN       NaN
# 75%      668.500000    1.000000    3.000000  ...   31.000000          NaN       NaN
# max      891.000000    1.000000    3.000000  ...  512.329200          NaN       NaN
#
# [11 rows x 12 columns]

# %%
train.describe()
# Out:
#        PassengerId    Survived      Pclass  ...       SibSp       Parch        Fare
# count   891.000000  891.000000  891.000000  ...  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642  ...    0.523008    0.381594   32.204208
# std     257.353842    0.486592    0.836071  ...    1.102743    0.806057   49.693429
# min       1.000000    0.000000    1.000000  ...    0.000000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000  ...    0.000000    0.000000    7.910400
# 50%     446.000000    0.000000    3.000000  ...    0.000000    0.000000   14.454200
# 75%     668.500000    1.000000    3.000000  ...    1.000000    0.000000   31.000000
# max     891.000000    1.000000    3.000000  ...    8.000000    6.000000  512.329200
#
# [8 rows x 7 columns]

# %%
# ()을 빼면 한 줄 한 줄 출력
train.describe
# Out:
# <bound method NDFrame.describe of      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]>

# %% [markdown]
# `dtypes` 모든 열의 데이터 종류를 보여줌

# %%
train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# `info()` 는 `dtypes` 의 좀  더 발전된 개념으로 데이터 타입뿐만 아니라 빈칸이 아닌 갯수까지 보여줌

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# `columns`은 데이터 프레임의 열의 제목들을 보여줌

# %%
train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# `shape` 은 행의 갯수와 열의 갯수를 보여줌

# %%
train.shape
# Out:
# (891, 12)

# %% [markdown]
# ## Part 2 : 파일 병합
#
# * ntrain과 ntest의 shape을 확보 (병합 한 것을 나중에 다시 갈라 놓기 위한 준비)
# * y_train은 알려진 결과 값이니 따로 저장
# * 테스트의 승객 아이디는 나중에 최종 결과에 넣을 것이기 때문에 따로 저장
# * train과 test를 병합하여 data 란 파일을 만듦.
#   - 문자로 된 것을 숫자로 바꾼다든가. 숫자를 인터발 별로 그룹화 한다든가 할 때 한꺼번에 하기 위해 병합

# %%
# 병합 준비
ntrain = train.shape[0]
ntest = test.shape[0]

# 아래는 따로 저장
y_train = train['Survived'].values
passId = test['PassengerId']

# 병함 파일 만들기
data = pd.concat((train, test))

# 데이터 행과 열의 크기는
print("data size is: {}".format(data.shape))
# Out:
# data size is: (1309, 12)

# %%
# ntrain 값
ntrain
# Out:
# 891

# %%
# ntest 값
ntest
# Out:
# 418

# %%
y_train[:10]
# Out:
# array([0, 1, 1, 1, 0, 0, 0, 0, 1, 1])

# %%
passId[:10]
# Out:
# 0    892
# 1    893
# 2    894
# 3    895
# 4    896
# 5    897
# 6    898
# 7    899
# 8    900
# 9    901
# Name: PassengerId, dtype: int64

# %%
# train과 test를 합친 data
# test에서 "Survived"는 빈칸(NaN - Not a Number)이 나타남 - 우리가 예측해야할 값
data
# Out:
#      PassengerId  Survived  Pclass  ...      Fare Cabin  Embarked
# 0              1       0.0       3  ...    7.2500   NaN         S
# 1              2       1.0       1  ...   71.2833   C85         C
# 2              3       1.0       3  ...    7.9250   NaN         S
# 3              4       1.0       1  ...   53.1000  C123         S
# 4              5       0.0       3  ...    8.0500   NaN         S
# ..           ...       ...     ...  ...       ...   ...       ...
# 413         1305       NaN       3  ...    8.0500   NaN         S
# 414         1306       NaN       1  ...  108.9000  C105         C
# 415         1307       NaN       3  ...    7.2500   NaN         S
# 416         1308       NaN       3  ...    8.0500   NaN         S
# 417         1309       NaN       3  ...   22.3583   NaN         C
#
# [1309 rows x 12 columns]

# %%
train['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %% [markdown]
# train 데이터에 있는 인원 중 342명이 살아남고 549명이 사망했다는 것을 볼 수 있음

# %% [markdown]
# ## Part 3 : 파일 탐색

# %%
missingno.matrix(data, figsize = (6,4))

# %% [markdown]
# 위 도표는 빈 값을 직관적으로 볼 수 있음.
# 아래 쪽 Survived가 비어 있는데 이 것은 `test`에 우리가 답으로 예측해야 하는 부분

# %%
# null 값 체크
data.isnull().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# dtype: int64

# %%
data.isna().any()
# Out:
# PassengerId    False
# Survived        True
# Pclass         False
# Name           False
# Sex            False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare            True
# Cabin           True
# Embarked        True
# dtype: bool

# %% [markdown]
# data.isnull.any() - 전체에 빈값이 있나 없나?  isna를 써도 같음 - 각 항목 별로
#
# data.isnull.sum() - 전체 각 항목 중 빈칸이 몇 개나 있나?
#
# data.isnull.any().any() - 전체에 빈값이 있나 없나? - 전체 True / False

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# ### Features 항목
#
# #### 항목의 종류
#
# - 범주형 항목 (Categorical Features)
#
#   - 범주형 항목은 범주형 변수로 된 항목으로 범주형 변수는 둘 이상의 결과 요소가 있는 변수이며 해당 기능의 각 값을 범주별로 분류
#
#   - 예를 들어 성별은 두 가지 범주 (남성과 여성)의 범주 형 변수
#
#   - 이산형 변수(discrete variable) = 범주형 변수 (categorical variable) 의 하나로 명목 변수 norminal variable
#
#         데이터 셋에서 명목 항목 : Sex, Embark 이며 우리는 Name, Ticket 등을 이로 변환해야 함
#
#
# - 순서형 변수 (Ordinal Variable)
#   - 순위 변수는 범주 형의 하나지만 그 차이점은 값 사이의 상대 순서(=서열) 또는 정렬이 가능
#
#         데이터 셋에서 순위 항목 : PClass 이며 우리는 Cabin을 이 범주로 변환해서 사용해야 함
#
#
# - 연속형 항목 (Continuous Features):
#
#   - 서로 연속된 값을 가진 변수를 가진 항목이며 여기에서 우리는 연령을 대표적인 것으로 볼 수 있음
#
#         Age, SipSp, Parch, Fare는 interval variable로 만들어 이에 적용해야 함
#
#
#
# * 아래의 항목에서 columns 이름 확인
#
#           Variable          정의                Key
#
#           survival          생존 여부            0 = No, 1 = Yes
#
#           pclass            선실 등급            1 = 1st, 2 = 2nd, 3 = 3rd
#
#           sex               성별
#
#           Age               나이
#
#           sibsp             형재 자매의 수/ 배우자 등이 승선한 경우 수
#
#           parch             부모나 자식과 같이 탄 경우 수
#
#           ticket            표 번호
#
#           fare              요금
#
#           cabin             선실 번호
#
#           embarked          승선한 항구         C = Cherbourg, Q = Queenstown, S = Southampton

# %% [markdown]
# ## Part 4 : 데이터 탐구 (Exploartory Data Analysis)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %% [markdown]
# * 데이터 각 column의 상관관계
#
#   - `Co-relation 매트릭스`는 `seaborn`에서 변수 간 상관 계수를 보여주는 표
#   - 표의 각 셀은 두 변수 간의 상관 관계를 보여줌
#   - 상관 매트릭스는 고급 분석에 대한 입력 및 고급 분석에 대한 진단으로 데이터를 요약하는 데 사용
#     - ref : https://seaborn.pydata.org/examples/many_pairwise_correlations.html
#
# - 아래 마스크 셋업은 0으로 행렬을 상관 행렬과 같은 모양으로 만든 후 여기에 불리안 값을 넣고 이를 다시 True만 만듦
#
# - triu 는 우측 상단 삼각행렬을 의미
#
# - annot= True는 각 셀에 숫자를 표시하라는 것이고, False는 하지 말라는 것
#
# - 이어서 이를 heatmap으로 시각화

# %%
# Co-relation 매트릭스
corr = data.corr()

# 마스크 셋업
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# 그래프 셋업
plt.figure(figsize=(14, 8))

# 그래프 타이틀
plt.title('Overall Correlation of Titanic Features', fontsize=18)

#  Co-relation 매트릭스 시각화
sns.heatmap(corr, mask=mask, annot=False,cmap='RdYlGn', linewidths=0.2, annot_kws={'size':20})
plt.show()

# %% [markdown]
# ### "Surived" 분석
#   - Survived - Key: (0 - Not Survived, 1- Survived)
#
#   - Survived는 숫자로 값을 주지만 범주형 변수(Categorical Variable)인 셈
#
#   - 죽던지 살던지 둘 중 하나의 값 부여
#
#   - countplot 시각화
#
#   - 사이즈는 가로 10인치 세로 2인치
#
#   - 생존 여부 0과 1의 count값

# %%
fig = plt.figure(figsize=(10,2))
sns.countplot(y='Survived', data=train)
print(train.Survived.value_counts())
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %% [markdown]
# - 전체 사망자 비율 확인하고자 함
#   - `pie plot`과 `count plot`을 서브플롯으로 시각화
#   - 행은 하나 열은 2개의 서브 플롯
#
# - 'Survived'의 `pie plot`
#   - `explode`가 1이면 튀어 나가는 것인데 0을 주면 분리만 되고 돌출은 되지 않음
#   - 0, 1인 것은 첫 번째 것은 아니고 두번 째 것은 분리된다는 의미로 생각하시면 됩니다.
#   - autopercent는 1.1이 표현하는 부분은 소수점 한 자리까지 보여 주라는 의미

# %%
f,ax=plt.subplots(1, 2, figsize=(15, 6))
train['Survived'].value_counts().plot.pie(explode=[0, 0.1], autopct='%1.1f%%', ax=ax[0], shadow=True)
ax[0].set_title('Survived')
ax[0].set_ylabel('')
sns.countplot('Survived',data=train, ax=ax[1])
ax[1].set_title('Survived')
plt.show()

# %% [markdown]
# - `pie plot`과 `count plot`을 함께 출력하는 함수 정의

# %%
def piecount(col):
    f, ax = plt.subplots(1, 2, figsize=(15, 6))
    train[col].value_counts().plot.pie(explode=[0.1 for i in range(train[col].nunique())], autopct='%1.1f%%', ax=ax[0], shadow=True)
    ax[0].set_title(col)
    ax[0].set_ylabel('')
    sns.countplot(col, data=train, ax=ax[1])
    ax[1].set_title(col)
    plt.show()

piecount('Survived')

# %% [markdown]
# ### "Pclass" 분석
#   - Pclass는 값이 숫자이나 서열이 정해진 순서형 변수 (Ordinal Feature)
#   - Key : 1 = 1st, 2 = 2nd, 3 = 3rd
#   - 각 클래스 당 생존자 확인하고자 함

# %%
train.groupby(['Pclass','Survived'])['Survived'].count()
# Out:
# Pclass  Survived
# 1       0            80
#         1           136
# 2       0            97
#         1            87
# 3       0           372
#         1           119
# Name: Survived, dtype: int64

# %%
pd.crosstab(train.Pclass, train.Survived, margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_e47e776e_1a96_11eb_a715_0242ac1c0002row0_col0,#T_e47e776e_1a96_11eb_a715_0242ac1c0002row1_col1,#T_e47e776e_1a96_11eb_a715_0242ac1c0002row1_col2{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_e47e776e_1a96_11eb_a715_0242ac1c0002row0_col1{
#             background-color:  #cee666;
#             color:  #000000;
#         }#T_e47e776e_1a96_11eb_a715_0242ac1c0002row0_col2{
#             background-color:  #f4fa66;
#             color:  #000000;
#         }#T_e47e776e_1a96_11eb_a715_0242ac1c0002row1_col0{
#             background-color:  #f6fa66;
#             color:  #000000;
#         }#T_e47e776e_1a96_11eb_a715_0242ac1c0002row2_col0{
#             background-color:  #60b066;
#             color:  #000000;
#         }#T_e47e776e_1a96_11eb_a715_0242ac1c0002row2_col1{
#             background-color:  #dfef66;
#             color:  #000000;
#         }#T_e47e776e_1a96_11eb_a715_0242ac1c0002row2_col2{
#             background-color:  #90c866;
#             color:  #000000;
#         }#T_e47e776e_1a96_11eb_a715_0242ac1c0002row3_col0,#T_e47e776e_1a96_11eb_a715_0242ac1c0002row3_col1,#T_e47e776e_1a96_11eb_a715_0242ac1c0002row3_col2{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_e47e776e_1a96_11eb_a715_0242ac1c0002" ><thead>    <tr>        <th class="index_name level0" >Survived</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >All</th>    </tr>    <tr>        <th class="index_name level0" >Pclass</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e47e776e_1a96_11eb_a715_0242ac1c0002level0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_e47e776e_1a96_11eb_a715_0242ac1c0002row0_col0" class="data row0 col0" >80</td>
#                         <td id="T_e47e776e_1a96_11eb_a715_0242ac1c0002row0_col1" class="data row0 col1" >136</td>
#                         <td id="T_e47e776e_1a96_11eb_a715_0242ac1c0002row0_col2" class="data row0 col2" >216</td>
#             </tr>
#             <tr>
#                         <th id="T_e47e776e_1a96_11eb_a715_0242ac1c0002level0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_e47e776e_1a96_11eb_a715_0242ac1c0002row1_col0" class="data row1 col0" >97</td>
#                         <td id="T_e47e776e_1a96_11eb_a715_0242ac1c0002row1_col1" class="data row1 col1" >87</td>
#                         <td id="T_e47e776e_1a96_11eb_a715_0242ac1c0002row1_col2" class="data row1 col2" >184</td>
#             </tr>
#             <tr>
#                         <th id="T_e47e776e_1a96_11eb_a715_0242ac1c0002level0_row2" class="row_heading level0 row2" >3</th>
#                         <td id="T_e47e776e_1a96_11eb_a715_0242ac1c0002row2_col0" class="data row2 col0" >372</td>
#                         <td id="T_e47e776e_1a96_11eb_a715_0242ac1c0002row2_col1" class="data row2 col1" >119</td>
#                         <td id="T_e47e776e_1a96_11eb_a715_0242ac1c0002row2_col2" class="data row2 col2" >491</td>
#             </tr>
#             <tr>
#                         <th id="T_e47e776e_1a96_11eb_a715_0242ac1c0002level0_row3" class="row_heading level0 row3" >All</th>
#                         <td id="T_e47e776e_1a96_11eb_a715_0242ac1c0002row3_col0" class="data row3 col0" >549</td>
#                         <td id="T_e47e776e_1a96_11eb_a715_0242ac1c0002row3_col1" class="data row3 col1" >342</td>
#                         <td id="T_e47e776e_1a96_11eb_a715_0242ac1c0002row3_col2" class="data row3 col2" >891</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# - 1등급 객실의 사람들은 생존자가 더 많음
# - 2등급은 생존자에 비해 사망자가 조금 더 많음
# - 3등급은 사망자가 3배 이상 많음

# %%
f, ax = plt.subplots(1, 2, figsize=(12, 6))
train[['Pclass','Survived']].groupby(['Pclass']).mean().plot.bar(ax=ax[0])
ax[0].set_title('Survived per Pcalss')
sns.countplot('Pclass', hue='Survived', data=train, ax=ax[1])
ax[1].set_title('Pcalss Survived vs Not Survived')
plt.show()

# %%
piecount("Pclass")

# %% [markdown]
# * 사망자 백분율은 3등칸이 반이 넘으나 위의 그래프에서 생존자는 1등석이 가장 많다는 것을 알 수 있음

# %% [markdown]
# ### "Name" 분석
#   - 이름은 거의 모두 다름
#         Family Name, First Name, Middle Name and even Dr. Capt, master 등
#   - 리스트 확인 후 분류 작업 실시

# %%
data.Name.value_counts()
# Out:
# Kelly, Mr. James                         2
# Connolly, Miss. Kate                     2
# Nicholls, Mr. Joseph Charles             1
# Jalsevac, Mr. Ivan                       1
# Pokrnic, Mr. Mate                        1
#                                         ..
# Bishop, Mr. Dickinson H                  1
# Lahtinen, Mrs. William (Anna Sylfven)    1
# Loring, Mr. Joseph Holland               1
# Nasser, Mrs. Nicholas (Adele Achem)      1
# Ashby, Mr. John                          1
# Name: Name, Length: 1307, dtype: int64

# %% [markdown]
# - 이름은 매우 다양하기에 호칭으로 분류
# - ['Initial']이란 열을 새로 만들어서 여기에 Name에서 추출한 정규표현 (Regular Expression)을 추가
# - 아래에서 str.extract('([A-Za-z]+).')부분은 str에서 대문자 A~Z, 소문자 a~z 중에 . 명령을 통해 .으로 끝나는 부분을 추출
# - ('^([A-Za-z]+)')으로 하면 처음에 나오는 문자 덩어리가 될 것이고 +를 빼면 첫 스펠링 한 글자만 추출

# %%
temp = data.copy()
temp['Initial'] = 0
temp['Initial'] = data.Name.str.extract('([A-Za-z0-9]+)\.')

# %%
temp['Initial'].value_counts()
# Out:
# Mr          757
# Miss        260
# Mrs         197
# Master       61
# Rev           8
# Dr            8
# Col           4
# Mlle          2
# Ms            2
# Major         2
# Jonkheer      1
# Mme           1
# Don           1
# Dona          1
# Countess      1
# Sir           1
# Capt          1
# Lady          1
# Name: Initial, dtype: int64

# %% [markdown]
# Miss나 Mr등은 많으나 익숙하지 않은 호칭들이 존재
# 이를 성별로 확인하고자 함

# %%
pd.crosstab(temp.Initial, temp.Sex).T.style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_e4dc31ce_1a96_11eb_a715_0242ac1c0002row0_col0,#T_e4dc31ce_1a96_11eb_a715_0242ac1c0002row0_col1,#T_e4dc31ce_1a96_11eb_a715_0242ac1c0002row0_col3,#T_e4dc31ce_1a96_11eb_a715_0242ac1c0002row0_col5,#T_e4dc31ce_1a96_11eb_a715_0242ac1c0002row0_col6,#T_e4dc31ce_1a96_11eb_a715_0242ac1c0002row0_col8,#T_e4dc31ce_1a96_11eb_a715_0242ac1c0002row0_col9,#T_e4dc31ce_1a96_11eb_a715_0242ac1c0002row0_col13,#T_e4dc31ce_1a96_11eb_a715_0242ac1c0002row0_col16,#T_e4dc31ce_1a96_11eb_a715_0242ac1c0002row0_col17,#T_e4dc31ce_1a96_11eb_a715_0242ac1c0002row1_col2,#T_e4dc31ce_1a96_11eb_a715_0242ac1c0002row1_col4,#T_e4dc31ce_1a96_11eb_a715_0242ac1c0002row1_col7,#T_e4dc31ce_1a96_11eb_a715_0242ac1c0002row1_col10,#T_e4dc31ce_1a96_11eb_a715_0242ac1c0002row1_col11,#T_e4dc31ce_1a96_11eb_a715_0242ac1c0002row1_col12,#T_e4dc31ce_1a96_11eb_a715_0242ac1c0002row1_col14,#T_e4dc31ce_1a96_11eb_a715_0242ac1c0002row1_col15{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_e4dc31ce_1a96_11eb_a715_0242ac1c0002row0_col2,#T_e4dc31ce_1a96_11eb_a715_0242ac1c0002row0_col4,#T_e4dc31ce_1a96_11eb_a715_0242ac1c0002row0_col7,#T_e4dc31ce_1a96_11eb_a715_0242ac1c0002row0_col10,#T_e4dc31ce_1a96_11eb_a715_0242ac1c0002row0_col11,#T_e4dc31ce_1a96_11eb_a715_0242ac1c0002row0_col12,#T_e4dc31ce_1a96_11eb_a715_0242ac1c0002row0_col14,#T_e4dc31ce_1a96_11eb_a715_0242ac1c0002row0_col15,#T_e4dc31ce_1a96_11eb_a715_0242ac1c0002row1_col0,#T_e4dc31ce_1a96_11eb_a715_0242ac1c0002row1_col1,#T_e4dc31ce_1a96_11eb_a715_0242ac1c0002row1_col3,#T_e4dc31ce_1a96_11eb_a715_0242ac1c0002row1_col5,#T_e4dc31ce_1a96_11eb_a715_0242ac1c0002row1_col6,#T_e4dc31ce_1a96_11eb_a715_0242ac1c0002row1_col8,#T_e4dc31ce_1a96_11eb_a715_0242ac1c0002row1_col9,#T_e4dc31ce_1a96_11eb_a715_0242ac1c0002row1_col13,#T_e4dc31ce_1a96_11eb_a715_0242ac1c0002row1_col16,#T_e4dc31ce_1a96_11eb_a715_0242ac1c0002row1_col17{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_e4dc31ce_1a96_11eb_a715_0242ac1c0002" ><thead>    <tr>        <th class="index_name level0" >Initial</th>        <th class="col_heading level0 col0" >Capt</th>        <th class="col_heading level0 col1" >Col</th>        <th class="col_heading level0 col2" >Countess</th>        <th class="col_heading level0 col3" >Don</th>        <th class="col_heading level0 col4" >Dona</th>        <th class="col_heading level0 col5" >Dr</th>        <th class="col_heading level0 col6" >Jonkheer</th>        <th class="col_heading level0 col7" >Lady</th>        <th class="col_heading level0 col8" >Major</th>        <th class="col_heading level0 col9" >Master</th>        <th class="col_heading level0 col10" >Miss</th>        <th class="col_heading level0 col11" >Mlle</th>        <th class="col_heading level0 col12" >Mme</th>        <th class="col_heading level0 col13" >Mr</th>        <th class="col_heading level0 col14" >Mrs</th>        <th class="col_heading level0 col15" >Ms</th>        <th class="col_heading level0 col16" >Rev</th>        <th class="col_heading level0 col17" >Sir</th>    </tr>    <tr>        <th class="index_name level0" >Sex</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e4dc31ce_1a96_11eb_a715_0242ac1c0002level0_row0" class="row_heading level0 row0" >female</th>
#                         <td id="T_e4dc31ce_1a96_11eb_a715_0242ac1c0002row0_col0" class="data row0 col0" >0</td>
#                         <td id="T_e4dc31ce_1a96_11eb_a715_0242ac1c0002row0_col1" class="data row0 col1" >0</td>
#                         <td id="T_e4dc31ce_1a96_11eb_a715_0242ac1c0002row0_col2" class="data row0 col2" >1</td>
#                         <td id="T_e4dc31ce_1a96_11eb_a715_0242ac1c0002row0_col3" class="data row0 col3" >0</td>
#                         <td id="T_e4dc31ce_1a96_11eb_a715_0242ac1c0002row0_col4" class="data row0 col4" >1</td>
#                         <td id="T_e4dc31ce_1a96_11eb_a715_0242ac1c0002row0_col5" class="data row0 col5" >1</td>
#                         <td id="T_e4dc31ce_1a96_11eb_a715_0242ac1c0002row0_col6" class="data row0 col6" >0</td>
#                         <td id="T_e4dc31ce_1a96_11eb_a715_0242ac1c0002row0_col7" class="data row0 col7" >1</td>
#                         <td id="T_e4dc31ce_1a96_11eb_a715_0242ac1c0002row0_col8" class="data row0 col8" >0</td>
#                         <td id="T_e4dc31ce_1a96_11eb_a715_0242ac1c0002row0_col9" class="data row0 col9" >0</td>
#                         <td id="T_e4dc31ce_1a96_11eb_a715_0242ac1c0002row0_col10" class="data row0 col10" >260</td>
#                         <td id="T_e4dc31ce_1a96_11eb_a715_0242ac1c0002row0_col11" class="data row0 col11" >2</td>
#                         <td id="T_e4dc31ce_1a96_11eb_a715_0242ac1c0002row0_col12" class="data row0 col12" >1</td>
#                         <td id="T_e4dc31ce_1a96_11eb_a715_0242ac1c0002row0_col13" class="data row0 col13" >0</td>
#                         <td id="T_e4dc31ce_1a96_11eb_a715_0242ac1c0002row0_col14" class="data row0 col14" >197</td>
#                         <td id="T_e4dc31ce_1a96_11eb_a715_0242ac1c0002row0_col15" class="data row0 col15" >2</td>
#                         <td id="T_e4dc31ce_1a96_11eb_a715_0242ac1c0002row0_col16" class="data row0 col16" >0</td>
#                         <td id="T_e4dc31ce_1a96_11eb_a715_0242ac1c0002row0_col17" class="data row0 col17" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_e4dc31ce_1a96_11eb_a715_0242ac1c0002level0_row1" class="row_heading level0 row1" >male</th>
#                         <td id="T_e4dc31ce_1a96_11eb_a715_0242ac1c0002row1_col0" class="data row1 col0" >1</td>
#                         <td id="T_e4dc31ce_1a96_11eb_a715_0242ac1c0002row1_col1" class="data row1 col1" >4</td>
#                         <td id="T_e4dc31ce_1a96_11eb_a715_0242ac1c0002row1_col2" class="data row1 col2" >0</td>
#                         <td id="T_e4dc31ce_1a96_11eb_a715_0242ac1c0002row1_col3" class="data row1 col3" >1</td>
#                         <td id="T_e4dc31ce_1a96_11eb_a715_0242ac1c0002row1_col4" class="data row1 col4" >0</td>
#                         <td id="T_e4dc31ce_1a96_11eb_a715_0242ac1c0002row1_col5" class="data row1 col5" >7</td>
#                         <td id="T_e4dc31ce_1a96_11eb_a715_0242ac1c0002row1_col6" class="data row1 col6" >1</td>
#                         <td id="T_e4dc31ce_1a96_11eb_a715_0242ac1c0002row1_col7" class="data row1 col7" >0</td>
#                         <td id="T_e4dc31ce_1a96_11eb_a715_0242ac1c0002row1_col8" class="data row1 col8" >2</td>
#                         <td id="T_e4dc31ce_1a96_11eb_a715_0242ac1c0002row1_col9" class="data row1 col9" >61</td>
#                         <td id="T_e4dc31ce_1a96_11eb_a715_0242ac1c0002row1_col10" class="data row1 col10" >0</td>
#                         <td id="T_e4dc31ce_1a96_11eb_a715_0242ac1c0002row1_col11" class="data row1 col11" >0</td>
#                         <td id="T_e4dc31ce_1a96_11eb_a715_0242ac1c0002row1_col12" class="data row1 col12" >0</td>
#                         <td id="T_e4dc31ce_1a96_11eb_a715_0242ac1c0002row1_col13" class="data row1 col13" >757</td>
#                         <td id="T_e4dc31ce_1a96_11eb_a715_0242ac1c0002row1_col14" class="data row1 col14" >0</td>
#                         <td id="T_e4dc31ce_1a96_11eb_a715_0242ac1c0002row1_col15" class="data row1 col15" >0</td>
#                         <td id="T_e4dc31ce_1a96_11eb_a715_0242ac1c0002row1_col16" class="data row1 col16" >8</td>

# %% [markdown]
# - 생존률을 확인하기 위한 함수 정의

# %%
def survpct(col):
    return temp.groupby(col)['Survived'].mean()

survpct('Initial')
# Out:
# Initial
# Capt        0.000000
# Col         0.500000
# Countess    1.000000
# Don         0.000000
# Dona             NaN
# Dr          0.428571
# Jonkheer    0.000000
# Lady        1.000000
# Major       0.500000
# Master      0.575000
# Miss        0.697802
# Mlle        1.000000
# Mme         1.000000
# Mr          0.156673
# Mrs         0.792000
# Ms          1.000000
# Rev         0.000000
# Sir         1.000000
# Name: Survived, dtype: float64

# %% [markdown]
# - test 에 있는 Dona의 나이를 보고 어디에 포함 시킬지 판단
# - Ms. 는 현대처럼 Miss + Mrs를 합친 말이 아니라 당시에는 귀족미망인을 의미
# - Mlle나 Mme등도 마드모아젤과 마담의 줄인말일 경우일 것(귀족 여성)

# %%
temp.loc[temp['Initial'] == 'Dona']
# Out:
#      PassengerId  Survived  Pclass  ... Cabin Embarked  Initial
# 414         1306       NaN       1  ...  C105        C     Dona
#
# [1 rows x 13 columns]

# %% [markdown]
# 나이로 추측해서 Mrs.로 변경

# %%
temp.loc[temp['Initial'] == 'Dona', 'Initial'] = 'Mrs'

# %%
pd.crosstab(temp.Initial, temp.Survived).T.style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_e4f22b1e_1a96_11eb_a715_0242ac1c0002row0_col0,#T_e4f22b1e_1a96_11eb_a715_0242ac1c0002row0_col3,#T_e4f22b1e_1a96_11eb_a715_0242ac1c0002row0_col4,#T_e4f22b1e_1a96_11eb_a715_0242ac1c0002row0_col5,#T_e4f22b1e_1a96_11eb_a715_0242ac1c0002row0_col12,#T_e4f22b1e_1a96_11eb_a715_0242ac1c0002row0_col15,#T_e4f22b1e_1a96_11eb_a715_0242ac1c0002row1_col2,#T_e4f22b1e_1a96_11eb_a715_0242ac1c0002row1_col6,#T_e4f22b1e_1a96_11eb_a715_0242ac1c0002row1_col8,#T_e4f22b1e_1a96_11eb_a715_0242ac1c0002row1_col9,#T_e4f22b1e_1a96_11eb_a715_0242ac1c0002row1_col10,#T_e4f22b1e_1a96_11eb_a715_0242ac1c0002row1_col11,#T_e4f22b1e_1a96_11eb_a715_0242ac1c0002row1_col13,#T_e4f22b1e_1a96_11eb_a715_0242ac1c0002row1_col14,#T_e4f22b1e_1a96_11eb_a715_0242ac1c0002row1_col16{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }#T_e4f22b1e_1a96_11eb_a715_0242ac1c0002row0_col1,#T_e4f22b1e_1a96_11eb_a715_0242ac1c0002row0_col2,#T_e4f22b1e_1a96_11eb_a715_0242ac1c0002row0_col6,#T_e4f22b1e_1a96_11eb_a715_0242ac1c0002row0_col7,#T_e4f22b1e_1a96_11eb_a715_0242ac1c0002row0_col8,#T_e4f22b1e_1a96_11eb_a715_0242ac1c0002row0_col9,#T_e4f22b1e_1a96_11eb_a715_0242ac1c0002row0_col10,#T_e4f22b1e_1a96_11eb_a715_0242ac1c0002row0_col11,#T_e4f22b1e_1a96_11eb_a715_0242ac1c0002row0_col13,#T_e4f22b1e_1a96_11eb_a715_0242ac1c0002row0_col14,#T_e4f22b1e_1a96_11eb_a715_0242ac1c0002row0_col16,#T_e4f22b1e_1a96_11eb_a715_0242ac1c0002row1_col0,#T_e4f22b1e_1a96_11eb_a715_0242ac1c0002row1_col1,#T_e4f22b1e_1a96_11eb_a715_0242ac1c0002row1_col3,#T_e4f22b1e_1a96_11eb_a715_0242ac1c0002row1_col4,#T_e4f22b1e_1a96_11eb_a715_0242ac1c0002row1_col5,#T_e4f22b1e_1a96_11eb_a715_0242ac1c0002row1_col7,#T_e4f22b1e_1a96_11eb_a715_0242ac1c0002row1_col12,#T_e4f22b1e_1a96_11eb_a715_0242ac1c0002row1_col15{
#             background-color:  #ffff66;
#             color:  #000000;
#         }</style><table id="T_e4f22b1e_1a96_11eb_a715_0242ac1c0002" ><thead>    <tr>        <th class="index_name level0" >Initial</th>        <th class="col_heading level0 col0" >Capt</th>        <th class="col_heading level0 col1" >Col</th>        <th class="col_heading level0 col2" >Countess</th>        <th class="col_heading level0 col3" >Don</th>        <th class="col_heading level0 col4" >Dr</th>        <th class="col_heading level0 col5" >Jonkheer</th>        <th class="col_heading level0 col6" >Lady</th>        <th class="col_heading level0 col7" >Major</th>        <th class="col_heading level0 col8" >Master</th>        <th class="col_heading level0 col9" >Miss</th>        <th class="col_heading level0 col10" >Mlle</th>        <th class="col_heading level0 col11" >Mme</th>        <th class="col_heading level0 col12" >Mr</th>        <th class="col_heading level0 col13" >Mrs</th>        <th class="col_heading level0 col14" >Ms</th>        <th class="col_heading level0 col15" >Rev</th>        <th class="col_heading level0 col16" >Sir</th>    </tr>    <tr>        <th class="index_name level0" >Survived</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e4f22b1e_1a96_11eb_a715_0242ac1c0002level0_row0" class="row_heading level0 row0" >0.0</th>
#                         <td id="T_e4f22b1e_1a96_11eb_a715_0242ac1c0002row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_e4f22b1e_1a96_11eb_a715_0242ac1c0002row0_col1" class="data row0 col1" >1</td>
#                         <td id="T_e4f22b1e_1a96_11eb_a715_0242ac1c0002row0_col2" class="data row0 col2" >0</td>
#                         <td id="T_e4f22b1e_1a96_11eb_a715_0242ac1c0002row0_col3" class="data row0 col3" >1</td>
#                         <td id="T_e4f22b1e_1a96_11eb_a715_0242ac1c0002row0_col4" class="data row0 col4" >4</td>
#                         <td id="T_e4f22b1e_1a96_11eb_a715_0242ac1c0002row0_col5" class="data row0 col5" >1</td>
#                         <td id="T_e4f22b1e_1a96_11eb_a715_0242ac1c0002row0_col6" class="data row0 col6" >0</td>
#                         <td id="T_e4f22b1e_1a96_11eb_a715_0242ac1c0002row0_col7" class="data row0 col7" >1</td>
#                         <td id="T_e4f22b1e_1a96_11eb_a715_0242ac1c0002row0_col8" class="data row0 col8" >17</td>
#                         <td id="T_e4f22b1e_1a96_11eb_a715_0242ac1c0002row0_col9" class="data row0 col9" >55</td>
#                         <td id="T_e4f22b1e_1a96_11eb_a715_0242ac1c0002row0_col10" class="data row0 col10" >0</td>
#                         <td id="T_e4f22b1e_1a96_11eb_a715_0242ac1c0002row0_col11" class="data row0 col11" >0</td>
#                         <td id="T_e4f22b1e_1a96_11eb_a715_0242ac1c0002row0_col12" class="data row0 col12" >436</td>
#                         <td id="T_e4f22b1e_1a96_11eb_a715_0242ac1c0002row0_col13" class="data row0 col13" >26</td>
#                         <td id="T_e4f22b1e_1a96_11eb_a715_0242ac1c0002row0_col14" class="data row0 col14" >0</td>
#                         <td id="T_e4f22b1e_1a96_11eb_a715_0242ac1c0002row0_col15" class="data row0 col15" >6</td>
#                         <td id="T_e4f22b1e_1a96_11eb_a715_0242ac1c0002row0_col16" class="data row0 col16" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_e4f22b1e_1a96_11eb_a715_0242ac1c0002level0_row1" class="row_heading level0 row1" >1.0</th>
#                         <td id="T_e4f22b1e_1a96_11eb_a715_0242ac1c0002row1_col0" class="data row1 col0" >0</td>
#                         <td id="T_e4f22b1e_1a96_11eb_a715_0242ac1c0002row1_col1" class="data row1 col1" >1</td>
#                         <td id="T_e4f22b1e_1a96_11eb_a715_0242ac1c0002row1_col2" class="data row1 col2" >1</td>
#                         <td id="T_e4f22b1e_1a96_11eb_a715_0242ac1c0002row1_col3" class="data row1 col3" >0</td>
#                         <td id="T_e4f22b1e_1a96_11eb_a715_0242ac1c0002row1_col4" class="data row1 col4" >3</td>
#                         <td id="T_e4f22b1e_1a96_11eb_a715_0242ac1c0002row1_col5" class="data row1 col5" >0</td>
#                         <td id="T_e4f22b1e_1a96_11eb_a715_0242ac1c0002row1_col6" class="data row1 col6" >1</td>
#                         <td id="T_e4f22b1e_1a96_11eb_a715_0242ac1c0002row1_col7" class="data row1 col7" >1</td>
#                         <td id="T_e4f22b1e_1a96_11eb_a715_0242ac1c0002row1_col8" class="data row1 col8" >23</td>
#                         <td id="T_e4f22b1e_1a96_11eb_a715_0242ac1c0002row1_col9" class="data row1 col9" >127</td>
#                         <td id="T_e4f22b1e_1a96_11eb_a715_0242ac1c0002row1_col10" class="data row1 col10" >2</td>
#                         <td id="T_e4f22b1e_1a96_11eb_a715_0242ac1c0002row1_col11" class="data row1 col11" >1</td>
#                         <td id="T_e4f22b1e_1a96_11eb_a715_0242ac1c0002row1_col12" class="data row1 col12" >81</td>
#                         <td id="T_e4f22b1e_1a96_11eb_a715_0242ac1c0002row1_col13" class="data row1 col13" >99</td>
#                         <td id="T_e4f22b1e_1a96_11eb_a715_0242ac1c0002row1_col14" class="data row1 col14" >1</td>
#                         <td id="T_e4f22b1e_1a96_11eb_a715_0242ac1c0002row1_col15" class="data row1 col15" >0</td>
#                         <td id="T_e4f22b1e_1a96_11eb_a715_0242ac1c0002row1_col16" class="data row1 col16" >1</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# - 성을 추출하는 작업
# - ML은 알파벳보다 숫자를 좋아하므로 숫자로 변환

# %%
temp['LastName'] = data.Name.str.extract('([A-Za-z]+)')

# %%
temp['NumName'] = temp['LastName'].factorize()[0]

# %%
pd.crosstab(temp.NumName, temp.Survived).T.style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col0,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col5,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col6,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col7,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col12,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col13,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col14,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col16,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col17,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col18,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col20,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col25,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col27,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col28,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col29,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col32,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col33,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col36,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col38,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col39,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col40,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col43,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col44,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col45,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col46,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col47,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col48,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col51,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col54,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col56,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col57,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col60,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col61,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col64,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col66,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col67,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col68,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col70,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col71,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col72,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col75,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col78,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col81,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col82,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col83,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col84,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col85,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col86,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col88,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col89,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col90,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col94,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col95,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col96,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col97,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col98,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col99,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col102,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col103,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col104,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col105,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col106,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col107,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col108,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col109,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col111,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col112,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col114,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col117,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col118,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col119,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col120,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col122,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col123,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col125,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col126,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col127,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col130,#T_e5a3be2e_1a96_11eb_a715_0242ac1c0002row0_col131,#T_e5a3be2e_1a96_11eb_a715_0242a ...

# %%
temp.loc[temp['NumName'] == 27]
# Out:
#      PassengerId  Survived  Pclass  ... NumInit LastName  NumName
# 28            29       1.0       3  ...       2        O       27
# 47            48       1.0       3  ...       2        O       27
# 186          187       1.0       3  ...       1        O       27
# 364          365       0.0       3  ...       0        O       27
# 459          460       0.0       3  ...       0        O       27
# 502          503       0.0       3  ...       2        O       27
# 552          553       0.0       3  ...       0        O       27
# 629          630       0.0       3  ...       0        O       27
# 653          654       1.0       3  ...       2        O       27
# 88           980       NaN       3  ...       8        O       27
# 358         1250       NaN       3  ...       0        O       27
# 380         1272       NaN       3  ...       0        O       27
#
# [12 rows x 16 columns]

# %% [markdown]
# ### "Sex" 분석

# %%
train[['Sex','Survived']].groupby(['Sex']).mean()
# Out:
#         Survived
# Sex
# female  0.742038
# male    0.188908

# %% [markdown]
# - 함수를 정의하여 분석

# %%
def bag(col, target, title, title1):
    f,ax=plt.subplots(1,2,figsize=(12,5))
    train.groupby([col])[target].mean().plot(kind='bar', ax=ax[0])
    ax[0].set_title(title)
    sns.countplot(col, hue=target, data=train, ax=ax[1])
    ax[1].set_title(title1)
    plt.show()

bag('Sex','Survived','Survived per Sex','Sex Survived vs Not Survived')

# %% [markdown]
# - 배에 있던 남자의 수는 여자의 수보다 훨씬 많은.
#   - 생존 여성 수는 남성 수의 거의 두 배
#   - 선박 여성의 생존율은 약 75 % 인 반면 남성의 생존율은 약 18-19 %
#
# - 남성/여성을 분류하는 것보다 좀 더 새분화하고자 함
#   - 예를 들어 아기들은 아기이지, 남자인지 여자인지 구명보트 태울 때 안 물어 볼 것이기 때문
#   - 또한 귀족 아기인지 서민의 아기인지 분류 가능
#   - 생존 Pclass별로 성별을 봅니다.

# %%
pd.crosstab([train.Sex, train.Survived],train.Pclass,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_e5f17f9c_1a96_11eb_a715_0242ac1c0002row0_col0,#T_e5f17f9c_1a96_11eb_a715_0242ac1c0002row0_col1,#T_e5f17f9c_1a96_11eb_a715_0242ac1c0002row0_col3,#T_e5f17f9c_1a96_11eb_a715_0242ac1c0002row3_col2{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_e5f17f9c_1a96_11eb_a715_0242ac1c0002row0_col2,#T_e5f17f9c_1a96_11eb_a715_0242ac1c0002row1_col2{
#             background-color:  #f1f866;
#             color:  #000000;
#         }#T_e5f17f9c_1a96_11eb_a715_0242ac1c0002row1_col0{
#             background-color:  #96cb66;
#             color:  #000000;
#         }#T_e5f17f9c_1a96_11eb_a715_0242ac1c0002row1_col1{
#             background-color:  #a3d166;
#             color:  #000000;
#         }#T_e5f17f9c_1a96_11eb_a715_0242ac1c0002row1_col3{
#             background-color:  #cfe766;
#             color:  #000000;
#         }#T_e5f17f9c_1a96_11eb_a715_0242ac1c0002row2_col0{
#             background-color:  #a7d366;
#             color:  #000000;
#         }#T_e5f17f9c_1a96_11eb_a715_0242ac1c0002row2_col1,#T_e5f17f9c_1a96_11eb_a715_0242ac1c0002row2_col3{
#             background-color:  #85c266;
#             color:  #000000;
#         }#T_e5f17f9c_1a96_11eb_a715_0242ac1c0002row2_col2{
#             background-color:  #6eb666;
#             color:  #000000;
#         }#T_e5f17f9c_1a96_11eb_a715_0242ac1c0002row3_col0{
#             background-color:  #cde666;
#             color:  #000000;
#         }#T_e5f17f9c_1a96_11eb_a715_0242ac1c0002row3_col1{
#             background-color:  #f0f866;
#             color:  #000000;
#         }#T_e5f17f9c_1a96_11eb_a715_0242ac1c0002row3_col3{
#             background-color:  #f7fb66;
#             color:  #000000;
#         }#T_e5f17f9c_1a96_11eb_a715_0242ac1c0002row4_col0,#T_e5f17f9c_1a96_11eb_a715_0242ac1c0002row4_col1,#T_e5f17f9c_1a96_11eb_a715_0242ac1c0002row4_col2,#T_e5f17f9c_1a96_11eb_a715_0242ac1c0002row4_col3{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_e5f17f9c_1a96_11eb_a715_0242ac1c0002" ><thead>    <tr>        <th class="blank" ></th>        <th class="index_name level0" >Pclass</th>        <th class="col_heading level0 col0" >1</th>        <th class="col_heading level0 col1" >2</th>        <th class="col_heading level0 col2" >3</th>        <th class="col_heading level0 col3" >All</th>    </tr>    <tr>        <th class="index_name level0" >Sex</th>        <th class="index_name level1" >Survived</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e5f17f9c_1a96_11eb_a715_0242ac1c0002level0_row0" class="row_heading level0 row0" rowspan=2>female</th>
#                         <th id="T_e5f17f9c_1a96_11eb_a715_0242ac1c0002level1_row0" class="row_heading level1 row0" >0</th>
#                         <td id="T_e5f17f9c_1a96_11eb_a715_0242ac1c0002row0_col0" class="data row0 col0" >3</td>
#                         <td id="T_e5f17f9c_1a96_11eb_a715_0242ac1c0002row0_col1" class="data row0 col1" >6</td>
#                         <td id="T_e5f17f9c_1a96_11eb_a715_0242ac1c0002row0_col2" class="data row0 col2" >72</td>
#                         <td id="T_e5f17f9c_1a96_11eb_a715_0242ac1c0002row0_col3" class="data row0 col3" >81</td>
#             </tr>
#             <tr>
#                                 <th id="T_e5f17f9c_1a96_11eb_a715_0242ac1c0002level1_row1" class="row_heading level1 row1" >1</th>
#                         <td id="T_e5f17f9c_1a96_11eb_a715_0242ac1c0002row1_col0" class="data row1 col0" >91</td>
#                         <td id="T_e5f17f9c_1a96_11eb_a715_0242ac1c0002row1_col1" class="data row1 col1" >70</td>
#                         <td id="T_e5f17f9c_1a96_11eb_a715_0242ac1c0002row1_col2" class="data row1 col2" >72</td>
#                         <td id="T_e5f17f9c_1a96_11eb_a715_0242ac1c0002row1_col3" class="data row1 col3" >233</td>
#             </tr>
#             <tr>
#                         <th id="T_e5f17f9c_1a96_11eb_a715_0242ac1c0002level0_row2" class="row_heading level0 row2" rowspan=2>male</th>
#                         <th id="T_e5f17f9c_1a96_11eb_a715_0242ac1c0002level1_row2" class="row_heading level1 row2" >0</th>
#                         <td id="T_e5f17f9c_1a96_11eb_a715_0242ac1c0002row2_col0" class="data row2 col0" >77</td>
#                         <td id="T_e5f17f9c_1a96_11eb_a715_0242ac1c0002row2_col1" class="data row2 col1" >91</td>
#                         <td id="T_e5f17f9c_1a96_11eb_a715_0242ac1c0002row2_col2" class="data row2 col2" >300</td>
#                         <td id="T_e5f17f9c_1a96_11eb_a715_0242ac1c0002row2_col3" class="data row2 col3" >468</td>
#             </tr>
#             <tr>
#                                 <th id="T_e5f17f9c_1a96_11eb_a715_0242ac1c0002level1_row3" class="row_heading level1 row3" >1</th>
#                         <td id="T_e5f17f9c_1a96_11eb_a715_0242ac1c0002row3_col0" class="data row3 col0" >45</td>
#                         <td id="T_e5f17f9c_1a96_11eb_a715_0242ac1c0002row3_col1" class="data row3 col1" >17</td>
#                         <td id="T_e5f17f9c_1a96_11eb_a715_0242ac1c0002row3_col2" class="data row3 col2" >47</td>
#                         <td id="T_e5f17f9c_1a96_11eb_a715_0242ac1c0002row3_col3" class="data row3 col3" >109</td>
#             </tr>
#             <tr>
#                         <th id="T_e5f17f9c_1a96_11eb_a715_0242ac1c0002level0_row4" class="row_heading level0 row4" >All</th>
#                         <th id="T_e5f17f9c_1a96_11eb_a715_0242ac1c0002level1_row4" class="row_heading level1 row4" ></th>
#                         <td id="T_e5f17f9c_1a96_11eb_a715_0242ac1c0002row4_col0" class="data row4 col0" >216</td>
#                         <td id="T_e5f17f9c_1a96_11eb_a715_0242ac1c0002row4_col1" class="data row4 col1" >184</td>
#                         <td id="T_e5f17f9c_1a96_11eb_a715_0242ac1c0002row4_col2" class="data row4 col2" >491</td>
#                         <td id="T_e5f17f9c_1a96_11eb_a715_0242ac1c0002row4_col3" class="data row4 col3" >891</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# - 클래스 별 사망자 차이는 확연하게 드러나나, 클래스와 큰 상관없이 남성들이 많은 사망자가 났다는 것을 알 수 있음

# %% [markdown]
# - "Sex"항목을 다음과 같이 나누는 것을 시도해보고자 함
#   - 먼저 결과 도출 후 재차 시도할 때 분류
# - 먼저는 __남자 : 1, 여자 : 2__ 로 분류하고자 함

# %%
# temp['Gender'] = 0
# temp.loc[(temp['Sex']=='male') & (temp[Pclass]== 1) ,'Gender']= 1
# temp.loc[(temp['Sex']=='male') & (temp[Pclass]== 2) ,'Gender']= 2
# temp.loc[(temp['Sex']=='male') & (temp[Pclass]== 3) ,'Gender']= 2
# temp.loc[(temp['Sex']=='female') & (temp[Pclass]== 1) ,'Gender']= 3
# temp.loc[(temp['Sex']=='female') & (temp[Pclass]== 2) ,'Gender']= 4
# temp.loc[(temp['Sex']=='female') & (temp[Pclass]== 3) ,'Gender']= 5
# temp.loc[temp['Age']<1.0 ,'Gender']= 6

# %%
temp['Gender'] = 0
temp.loc[(temp['Sex']=='male') ,'Gender']= 1
temp.loc[(temp['Sex']=='female'),'Gender']= 2

# %%
temp.head()
# Out:
#    PassengerId  Survived  Pclass  ...   LastName NumName  Gender
# 0            1       0.0       3  ...     Braund       0       1
# 1            2       1.0       1  ...    Cumings       1       2
# 2            3       1.0       3  ...  Heikkinen       2       2
# 3            4       1.0       1  ...   Futrelle       3       2
# 4            5       0.0       3  ...      Allen       4       1
#
# [5 rows x 17 columns]

# %% [markdown]
# ### "Age" 분석
# - Age는 연속한 값
# - 결측치가 많으므로 보간하는 과정을 중심으로 다루고자 함
# - 먼저, Age의 최대,최소,중간값을 확인하고자함

# %%
print('Oldest Passenger was', data['Age'].max(), 'Years')
print('Youngest Passenger was', data['Age'].min(), 'Years')
print('Average Age on the ship was', int(data['Age'].mean()), 'Years')
# Out:
# Oldest Passenger was 80.0 Years
# Youngest Passenger was 0.17 Years
# Average Age on the ship was 29 Years

# %%
sns.swarmplot(x=train['Survived'], y=train['Age'])
plt.xlabel("Survived")
plt.ylabel("Age")
plt.show()

# %%
f, ax = plt.subplots(1,2,figsize=(9,4))
sns.violinplot("Pclass", "Age", hue="Survived", data=train, split=True, ax=ax[0])
ax[0].set_title('Pclass and Age vs Survived')
ax[0].set_yticks(range(0, 110, 10))
sns.violinplot("Sex","Age", hue="Survived", data=train, split=True, ax=ax[1])
ax[1].set_title('Sex and Age vs Survived')
ax[1].set_yticks(range(0, 110, 10))
plt.show()

# %% [markdown]
# - 관찰
#   1. Pclass에 따라 어린이 수가 증가, 10 세 미만의 어린이 (즉, 어린이)의 생존율은 Pclass에 상관없이 양호 보임
#
#   2. Pclass1에서 20-50세의 Passeneger의 생존 가능성은 높고 여성인 경우 더 높음
#
#   3. 남성의 경우 생존 확률은 나이가 증가함에 따라 감소

# %% [markdown]
# - 먼저 age의 결측치 처리부터 하고자 함
#
# - 앞에서 살펴본 것처럼 Age 항목에는 177 null 값 존재
#   - 이러한 NaN 값을 대체하기 위해 데이터 집합의 평균 수명을 지정
#
# - 문제는 평균 연령이 29 세를 4세 아이에게 할당하게 됨
#   - 승객이 어떤 연령대에 있는지 이름에서 힌트를 찾고자 함

# %% [markdown]
# - Initial별 평균 연령을 보고 Age에 적용시키고자 함

# %%
temp.groupby('Initial').agg({'Age': ['mean', 'count']}) #이니셜 별 평균 연령 체크
# Out:
#                 Age
#                mean count
# Initial
# Capt      70.000000     1
# Col       54.000000     4
# Countess  33.000000     1
# Don       40.000000     1
# Dr        43.571429     7
# Jonkheer  38.000000     1
# Lady      48.000000     1
# Major     48.500000     2
# Master     5.482642    53
# Miss      21.774238   210
# Mlle      24.000000     2
# Mme       24.000000     1
# Mr        32.252151   581
# Mrs       37.005848   171
# Ms        28.000000     1
# Rev       41.250000     8
# Sir       49.000000     1

# %%
# 이니셜 별 평균 연령을 빈값에 넣어 봅니다.

temp = temp.reset_index(drop=True)

temp['Age'] = temp.groupby('Initial')['Age'].apply(lambda x: x.fillna(x.mean()))

temp[31:50]
# Out:
#     PassengerId  Survived  Pclass  ...   LastName NumName  Gender
# 31           32       1.0       1  ...    Spencer      30       2
# 32           33       1.0       3  ...      Glynn      31       2
# 33           34       0.0       2  ...    Wheadon      32       1
# 34           35       0.0       1  ...      Meyer      33       1
# 35           36       0.0       1  ...  Holverson      34       1
# 36           37       1.0       3  ...      Mamee      35       1
# 37           38       0.0       3  ...       Cann      36       1
# 38           39       0.0       3  ...     Vander      18       2
# 39           40       1.0       3  ...     Nicola      37       2
# 40           41       0.0       3  ...      Ahlin      38       2
# 41           42       0.0       2  ...     Turpin      39       2
# 42           43       0.0       3  ...     Kraeff      40       1
# 43           44       1.0       2  ...    Laroche      41       2
# 44           45       1.0       3  ...    Devaney      42       2
# 45           46       0.0       3  ...     Rogers      43       1
# 46           47       0.0       3  ...     Lennon      44       1
# 47           48       1.0       3  ...          O      27       2
# 48           49       0.0       3  ...     Samaan      45       1
# 49           50       0.0       3  ...     Arnold      46       2
#
# [19 rows x 17 columns]

# %% [markdown]
# - Initial을 정리

# %%
temp['Initial'].replace(['Capt', 'Col', 'Countess', 'Don', 'Dona' , 'Dr', 'Jonkheer', 'Lady', 'Major', 'Master',  'Miss'  ,'Mlle', 'Mme', 'Mr', 'Mrs', 'Ms', 'Rev', 'Sir'], ['Sacrificed', 'Respected', 'Nobles', 'Mr', 'Mrs', 'Respected', 'Mr', 'Nobles', 'Respected', 'Kids', 'Miss', 'Nobles', 'Nobles', 'Mr', 'Mrs', 'Nobles', 'Sacrificed', 'Nobles'],inplace=True)
temp['Initial'].replace(['Kids', 'Miss', 'Mr', 'Mrs', 'Nobles', 'Respected', 'Sacrificed'], [4, 4, 2, 5, 6, 3, 1], inplace=True)

# %%
temp['Age_Range'] = pd.qcut(temp['Age'], 10)

# %%
survpct('Age_Range')
# Out:
# Age_Range
# (0.169, 16.0]     0.548077
# (16.0, 21.0]      0.307692
# (21.0, 23.0]      0.487179
# (23.0, 26.0]      0.369863
# (26.0, 30.0]      0.400000
# (30.0, 32.252]    0.198718
# (32.252, 33.0]    0.411765
# (33.0, 39.0]      0.504762
# (39.0, 48.0]      0.357143
# (48.0, 80.0]      0.387500
# Name: Survived, dtype: float64

# %%
temp['Agroup'] = 0

temp.loc[temp['Age'] < 1.0, 'Agroup'] = 1
temp.loc[(temp['Age'] >=1.0) & (temp['Age'] <= 3.0), 'Agroup'] = 2
temp.loc[(temp['Age'] > 3.0) & (temp['Age'] < 11.0), 'Agroup'] = 7
temp.loc[(temp['Age'] >= 11.0) & (temp['Age'] < 15.0), 'Agroup'] = 13
temp.loc[(temp['Age'] >= 15.0) & (temp['Age'] < 18.0), 'Agroup'] = 16
temp.loc[(temp['Age'] >= 18.0) & (temp['Age'] <=  20.0), 'Agroup'] = 18
temp.loc[(temp['Age'] > 20.0) & (temp['Age'] <= 22.0), 'Agroup'] = 21
temp.loc[(temp['Age'] > 22.0) & (temp['Age'] <= 26.0), 'Agroup'] = 24
temp.loc[(temp['Age'] > 26.0) & (temp['Age'] <= 30.0), 'Agroup'] = 28
temp.loc[(temp['Age'] > 30.0) & (temp['Age'] <= 32.0), 'Agroup'] = 31
temp.loc[(temp['Age'] > 32.0) & (temp['Age'] <= 34.0), 'Agroup'] = 33
temp.loc[(temp['Age'] > 34.0) & (temp['Age'] <= 38.0), 'Agroup'] = 36
temp.loc[(temp['Age'] > 38.0) & (temp['Age'] <= 52.0), 'Agroup'] = 45
temp.loc[(temp['Age'] > 52.0) & (temp['Age'] <= 75.0), 'Agroup'] = 60
temp.loc[temp['Age'] > 75.0, 'Agroup'] = 78

# %%
temp.head()
# Out:
#    PassengerId  Survived  Pclass  ... Gender     Age_Range  Agroup
# 0            1       0.0       3  ...      1  (21.0, 23.0]      21
# 1            2       1.0       1  ...      2  (33.0, 39.0]      36
# 2            3       1.0       3  ...      2  (23.0, 26.0]      24
# 3            4       1.0       1  ...      2  (33.0, 39.0]      36
# 4            5       0.0       3  ...      1  (33.0, 39.0]      36
#
# [5 rows x 19 columns]

# %% [markdown]
# - Age는 그룹화 시키면 좋으나 학습을 위해 놓아두고, 그룹화 연습은 Fare로 하고자 함
# - 위를 보고 sex를 남,녀,1세 이하 아기로 나누도록함
#   - 1, 2, 3을 부여

# %%
temp.loc[(temp['Sex'] == 'male'), 'Sex'] = 1
temp.loc[(temp['Sex'] == 'female'), 'Sex'] = 2
temp.loc[(temp['Age'] < 1), 'Sex'] = 3

# %%
survpct('Sex')
# Out:
# Sex
# 1    0.181818
# 2    0.740385
# 3    1.000000
# Name: Survived, dtype: float64

# %% [markdown]
# - Family or Alone
#   - "SibSp" + "Parch" 분석
#
#   - SibSp - 이 항목은 탑승자가 혼자인지 또는 가족과 함께 있는지를 나타냄
#         *Sibling = 형제, 자매, 의붓 형제, 이복 누이
#         *Spouse = 남편, 아내
#   - Parch는 부모와 함께 탔는지를 봅니다.
#
#   - 이 그룹 둘을 'Alone"그룹과 "Family'그룹으로 분리

# %%
temp.loc[(temp['SibSp'] == 0) & (temp['Parch'] == 0), 'Alone'] = 1

# %%
temp['Family'] = temp['Parch'] + temp['SibSp'] + 1

# %%
temp.head(10)
# Out:
#    PassengerId  Survived  Pclass  ... Agroup Alone  Family
# 0            1       0.0       3  ...     21   NaN       2
# 1            2       1.0       1  ...     36   NaN       2
# 2            3       1.0       3  ...     24   1.0       1
# 3            4       1.0       1  ...     36   NaN       2
# 4            5       0.0       3  ...     36   1.0       1
# 5            6       0.0       3  ...     33   1.0       1
# 6            7       0.0       1  ...     60   1.0       1
# 7            8       0.0       3  ...      2   NaN       5
# 8            9       1.0       3  ...     28   NaN       3
# 9           10       1.0       2  ...     13   NaN       2
#
# [10 rows x 21 columns]

# %%
survpct('Family')
# Out:
# Family
# 1     0.303538
# 2     0.552795
# 3     0.578431
# 4     0.724138
# 5     0.200000
# 6     0.136364
# 7     0.333333
# 8     0.000000
# 11    0.000000
# Name: Survived, dtype: float64

# %%
bag('Parch', 'Survived', 'Survived per Parch', 'Parch Survived vs Not Survived')

# %%
pd.crosstab([temp.Family, temp.Survived], temp.Pclass, margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_9aae0684_1aa2_11eb_a715_0242ac1c0002row0_col0,#T_9aae0684_1aa2_11eb_a715_0242ac1c0002row3_col0{
#             background-color:  #c3e166;
#             color:  #000000;
#         }#T_9aae0684_1aa2_11eb_a715_0242ac1c0002row0_col1{
#             background-color:  #a1d066;
#             color:  #000000;
#         }#T_9aae0684_1aa2_11eb_a715_0242ac1c0002row0_col2{
#             background-color:  #7bbd66;
#             color:  #000000;
#         }#T_9aae0684_1aa2_11eb_a715_0242ac1c0002row0_col3{
#             background-color:  #95ca66;
#             color:  #000000;
#         }#T_9aae0684_1aa2_11eb_a715_0242ac1c0002row1_col0{
#             background-color:  #bbdd66;
#             color:  #000000;
#         }#T_9aae0684_1aa2_11eb_a715_0242ac1c0002row1_col1{
#             background-color:  #cde666;
#             color:  #000000;
#         }#T_9aae0684_1aa2_11eb_a715_0242ac1c0002row1_col2{
#             background-color:  #dcee66;
#             color:  #000000;
#         }#T_9aae0684_1aa2_11eb_a715_0242ac1c0002row1_col3{
#             background-color:  #d1e866;
#             color:  #000000;
#         }#T_9aae0684_1aa2_11eb_a715_0242ac1c0002row2_col0,#T_9aae0684_1aa2_11eb_a715_0242ac1c0002row2_col1{
#             background-color:  #e9f466;
#             color:  #000000;
#         }#T_9aae0684_1aa2_11eb_a715_0242ac1c0002row2_col2,#T_9aae0684_1aa2_11eb_a715_0242ac1c0002row2_col3{
#             background-color:  #ecf666;
#             color:  #000000;
#         }#T_9aae0684_1aa2_11eb_a715_0242ac1c0002row3_col1{
#             background-color:  #e6f266;
#             color:  #000000;
#         }#T_9aae0684_1aa2_11eb_a715_0242ac1c0002row3_col2,#T_9aae0684_1aa2_11eb_a715_0242ac1c0002row5_col2{
#             background-color:  #f5fa66;
#             color:  #000000;
#         }#T_9aae0684_1aa2_11eb_a715_0242ac1c0002row3_col3{
#             background-color:  #e7f366;
#             color:  #000000;
#         }#T_9aae0684_1aa2_11eb_a715_0242ac1c0002row4_col0{
#             background-color:  #f8fc66;
#             color:  #000000;
#         }#T_9aae0684_1aa2_11eb_a715_0242ac1c0002row4_col1,#T_9aae0684_1aa2_11eb_a715_0242ac1c0002row7_col1{
#             background-color:  #f2f866;
#             color:  #000000;
#         }#T_9aae0684_1aa2_11eb_a715_0242ac1c0002row4_col2{
#             background-color:  #f1f866;
#             color:  #000000;
#         }#T_9aae0684_1aa2_11eb_a715_0242ac1c0002row4_col3{
#             background-color:  #f4fa66;
#             color:  #000000;
#         }#T_9aae0684_1aa2_11eb_a715_0242ac1c0002row5_col0{
#             background-color:  #eaf466;
#             color:  #000000;
#         }#T_9aae0684_1aa2_11eb_a715_0242ac1c0002row5_col1{
#             background-color:  #e2f066;
#             color:  #000000;
#         }#T_9aae0684_1aa2_11eb_a715_0242ac1c0002row5_col3{
#             background-color:  #eff766;
#             color:  #000000;
#         }#T_9aae0684_1aa2_11eb_a715_0242ac1c0002row6_col0,#T_9aae0684_1aa2_11eb_a715_0242ac1c0002row8_col3,#T_9aae0684_1aa2_11eb_a715_0242ac1c0002row9_col0,#T_9aae0684_1aa2_11eb_a715_0242ac1c0002row10_col0,#T_9aae0684_1aa2_11eb_a715_0242ac1c0002row11_col0,#T_9aae0684_1aa2_11eb_a715_0242ac1c0002row13_col2{
#             background-color:  #fdfe66;
#             color:  #000000;
#         }#T_9aae0684_1aa2_11eb_a715_0242ac1c0002row6_col1,#T_9aae0684_1aa2_11eb_a715_0242ac1c0002row10_col3,#T_9aae0684_1aa2_11eb_a715_0242ac1c0002row12_col2{
#             background-color:  #fbfd66;
#             color:  #000000;
#         }#T_9aae0684_1aa2_11eb_a715_0242ac1c0002row6_col2,#T_9aae0684_1aa2_11eb_a715_0242ac1c0002row6_col3,#T_9aae0684_1aa2_11eb_a715_0242ac1c0002row9_col1,#T_9aae0684_1aa2_11eb_a715_0242ac1c0002row11_col1,#T_9aae0684_1aa2_11eb_a715_0242ac1c0002row12_col3,#T_9aae0684_1aa2_11eb_a715_0242ac1c0002row15_col3{
#             background-color:  #fefe66;
#             color:  #000000;
#         }#T_9aae0684_1aa2_11eb_a715_0242ac1c0002row7_col0,#T_9aae0684_1aa2_11eb_a715_0242ac1c0002row7_col3{
#             background-color:  #fafc66;
#             color:  #000000;
#         }#T_9aae0684_1aa2_11eb_a715_0242ac1c0002row7_col2,#T_9aae0684_1aa2_11eb_a715_0242ac1c0002row14_col2,#T_9aae0684_1aa2_11eb_a715_0242ac1c0002row15_col2{
#             background-color:  #fcfe66;
#             color:  #000000;
#         }#T_9aae0684_1aa2_11eb_a715_0242ac1c0002row8_col0,#T_9aae0684_1aa2_11eb_a715_0242ac1c0002row8_col1,#T_9aae0684_1aa2_11eb_a715_0242ac1c0002row9_col2,#T_9aae0684_1aa2_11eb_a715_0242ac1c0002row9_col3,#T_9aae0684_1aa2_11eb_a715_0242ac1c0002row10_col1,#T_9aae0684_1aa2_11eb_a715_0242ac1c0002row11_col2,#T_9aae0684_1aa2_11eb_a715_0242ac1c0002row11_col3,#T_9aae0684_1aa2_11eb_a715_0242ac1c0002row12_col0,#T_9aae0684_1aa2_11eb_a715_0242ac1c0002row12_col1,#T_9aae0684_1aa2_11eb_a715_0242ac1c0002row13_col0,#T_9aae0684_1aa2_11eb_a715_0242ac1c0002row13_col1,#T_9aae0684_1aa2_11eb_a715_0242ac1c0002row13_col3,#T_9aae0684_1aa2_11eb_a715_0242ac1c0002row14_col0,#T_9aae0684_1aa2_11eb_a715_0242ac1c0002row14_col1,#T_9aae0684_1aa2_11eb_a715_0242ac1c0002row14_col3,#T_9aae0684_1aa2_11eb_a715_0242ac1c0002row15_col0,#T_9aae0684_1aa2_11eb_a715_0242ac1c0002row15_col1{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_9aae0684_1aa2_11eb_a715_0242ac1c0002row8_col2{
#             background-color:  #f9fc66;
#             color:  #000000;
#         }#T_9aae0684_1aa2_11eb_a715_0242ac1c0002row10_col2{
#             background-color:  #f7fb66;
#             color:  #000000;
#         }#T_9aae0684_1aa2_11eb_a715_0242ac1c0002row16_col0,#T_9aae0684_1aa2_11eb_a715_0242ac1c0002row16_col1,#T_9aae0684_1aa2_11eb_a715_0242ac1c0002row16_col2,#T_9aae0684_1aa2_11eb_a715_0242ac1c0002row16_col3{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_9aae0684_1aa2_11eb_a715_0242ac1c0002" ><thead>    <tr>        <th class="blank" ></th>        <th class="index_name level0" >Pclass</th>        <th class="col_heading level0 col0" >1</th>        <th class="col_heading level0 col1" >2</th>        <th class="col_heading level0 col2" >3</th>        <th class="col_heading level0 col3" >All</th>    </tr>    <tr>        <th class="index_name level0" >Family</th>        <th class="index_name level1" >Survived</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9aae0684_1aa2_11eb_a715_0242ac1c0002level0_row0" class="row_heading level0 row0" rowspan=2>1</th>
#                         <th id="T_9aae0684_1aa2_11eb_a715_0242ac1c0002level1_row0" class="row_heading level1 row0" >0.0</th>
#                         <td id="T_9aae0684_1aa2_11eb_a715_0242ac1c0002row0_col0" class="data row0 col0" >51</td>
#                         <td id="T_9aae0684_1aa2_11eb_a715_0242ac1c0002row0_col1" class="data row0 col1" >68</td>
#                         <td id="T_9aae0684_1aa2_11eb_a715_0242ac1c0002row0_col2" class="data row0 col2" >255</td>
#                         <td id="T_9aae0684_1aa2_11eb_a715_0242ac1c0002row0_col3" class="data row0 col3" >374</td>
#             </tr>
#             <tr>
#                                 <th id="T_9aae0684_1aa2_11eb_a715_0242ac1c0002level1_row1" class="row_heading level1 row1" >1.0</th>
#                         <td id="T_9aae0684_1aa2_11eb_a715_0242ac1c0002row1_col0" class="data row1 col0" >58</td>
#                         <td id="T_9aae0684_1aa2_11eb_a715_0242ac1c0002row1_col1" class="data row1 col1" >36</td>
#                         <td id="T_9aae0684_1aa2_11eb_a715_0242ac1c0002row1_col2" class="data row1 col2" >69</td>
#                         <td id="T_9aae0684_1aa2_11eb_a715_0242ac1c0002row1_col3" class="data row1 col3" >163</td>
#             </tr>
#             <tr>
#                         <th id="T_9aae0684_1aa2_11eb_a715_0242ac1c0002level0_row2" class="row_heading level0 row2" rowspan=2>2</th>
#                         <th id="T_9aae0684_1aa2_11eb_a715_0242ac1c0002level1_row2" class="row_heading level1 row2" >0.0</th>
#                         <td id="T_9aae0684_

# %% [markdown]
# - 크로스 탭은 식구 많은 쪽은 Pclass3에 있음을 보여줌
#
# - 부모와 함께 탑승 한 승객은 생존 가능성이 더 높음
#   - 그러나 숫자가 올라 갈수록 줄어듬
#
# - 생존 가능성은 배에 1-3명의 동행이 있는 탑승자에게 좋음
#   - 1인 탑승자는 생존 가능성이 낮음
#   - 가족이 4 명이상 있으면 생존 가능성이 줄어 듬
#     - 이는 소수의 가족들이 있는 귀족층이 생존
#     - 1인으로 탑승한 젊은이들은 양보
#     - 가족이 많은 탑승객(특히 귀족이 아닌 3등칸 탑승객)은 전원이 타지 못 하면 어느 누구도 탈 수가 없는 비극적인 당시 상황을 보여줌

# %% [markdown]
# ### "Ticket" 분석
# - Ticket의 형태를 보고자 함

# %%
temp.Ticket.head()
# Out:
# 0           A/5 21171
# 1            PC 17599
# 2    STON/O2. 3101282
# 3              113803
# 4              373450
# Name: Ticket, dtype: object

# %% [markdown]
# - 값에 규칙성이 보이지 않음
# - 결측치를 확인해보고자 함

# %%
temp.Ticket.isnull().sum()
# Out:
# 0

# %% [markdown]
# - 티켓의 영문과 숫자를 따로 확인하고자 함

# %%
temp['Initick'] = temp.Ticket.str.extract('^([A-Za-z0-9]+)')

temp.head()
# Out:
#    PassengerId  Survived  Pclass  ... Alone Family  Initick
# 0            1       0.0       3  ...   NaN      2        A
# 1            2       1.0       1  ...   NaN      2       PC
# 2            3       1.0       3  ...   1.0      1     STON
# 3            4       1.0       1  ...   NaN      2   113803
# 4            5       0.0       3  ...   1.0      1   373450
#
# [5 rows x 22 columns]

# %%
temp['Initick'] = temp.Ticket.str.extract('^([A-Za-z]+)')
temp.head()
# Out:
#    PassengerId  Survived  Pclass  ... Family Initick  NumTicket
# 0            1       0.0       3  ...      2       A          0
# 1            2       1.0       1  ...      2      PC          1
# 2            3       1.0       3  ...      1    STON          2
# 3            4       1.0       1  ...      2     NaN          3
# 4            5       0.0       3  ...      1     NaN          4
#
# [5 rows x 23 columns]

# %%
temp['NumTicket'] = temp['Initick'].factorize()[0]
temp.head(15)
# Out:
#     PassengerId  Survived  Pclass  ... Family Initick  NumTicket
# 0             1       0.0       3  ...      2       A          0
# 1             2       1.0       1  ...      2      PC          1
# 2             3       1.0       3  ...      1    STON          2
# 3             4       1.0       1  ...      2     NaN         -1
# 4             5       0.0       3  ...      1     NaN         -1
# 5             6       0.0       3  ...      1     NaN         -1
# 6             7       0.0       1  ...      1     NaN         -1
# 7             8       0.0       3  ...      5     NaN         -1
# 8             9       1.0       3  ...      3     NaN         -1
# 9            10       1.0       2  ...      2     NaN         -1
# 10           11       1.0       3  ...      3      PP          3
# 11           12       1.0       1  ...      1     NaN         -1
# 12           13       0.0       3  ...      1       A          0
# 13           14       0.0       3  ...      7     NaN         -1
# 14           15       0.0       3  ...      1     NaN         -1
#
# [15 rows x 23 columns]

# %%
temp.groupby('NumTicket')['Survived'].mean().to_frame().plot(kind='hist')
plt.title('Distribution of survival rate for different tickets');

# %% [markdown]
# ### "Fare" 분석

# %%
print('Highest Fare was:', temp['Fare'].max())
print('Lowest Fare was:', temp['Fare'].min())
print('Average Fare was:', temp['Fare'].mean())
# Out:
# Highest Fare was: 512.3292
# Lowest Fare was: 0.0
# Average Fare was: 33.2954792813456

# %%
f,ax=plt.subplots(1, 3, figsize=(10, 3))
sns.distplot(train[train['Pclass'] == 1].Fare,ax=ax[0])
ax[0].set_title('Fares in Pclass 1')
sns.distplot(train[train['Pclass'] == 2].Fare,ax=ax[1])
ax[1].set_title('Fares in Pclass 2')
sns.distplot(train[train['Pclass'] == 3].Fare,ax=ax[2])
ax[2].set_title('Fares in Pclass 3')
plt.show()

# %% [markdown]
# * Pclass1의 승객 요금에는 큰 분포가있는 것으로 보이며 범주항목으로 분류 가능
# * Fare를 그룹으로 분류
# * qcut을 활용하면 원하는 조각으로 데이터를 분할 가능

# %%
def groupmean(a,b):
    return temp.groupby([a])[b].mean().to_frame().style.background_gradient(cmap='summer_r')

temp['Fare_Range'] = pd.qcut(train['Fare'], 10)
groupmean('Fare_Range', 'Fare')
# Out:
# <style  type="text/css" >
# #T_3b4a0f00_1aa5_11eb_a715_0242ac1c0002row0_col0{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_3b4a0f00_1aa5_11eb_a715_0242ac1c0002row1_col0,#T_3b4a0f00_1aa5_11eb_a715_0242ac1c0002row2_col0{
#             background-color:  #fcfe66;
#             color:  #000000;
#         }#T_3b4a0f00_1aa5_11eb_a715_0242ac1c0002row3_col0{
#             background-color:  #f9fc66;
#             color:  #000000;
#         }#T_3b4a0f00_1aa5_11eb_a715_0242ac1c0002row4_col0{
#             background-color:  #f3f966;
#             color:  #000000;
#         }#T_3b4a0f00_1aa5_11eb_a715_0242ac1c0002row5_col0{
#             background-color:  #ebf566;
#             color:  #000000;
#         }#T_3b4a0f00_1aa5_11eb_a715_0242ac1c0002row6_col0{
#             background-color:  #dcee66;
#             color:  #000000;
#         }#T_3b4a0f00_1aa5_11eb_a715_0242ac1c0002row7_col0{
#             background-color:  #d0e866;
#             color:  #000000;
#         }#T_3b4a0f00_1aa5_11eb_a715_0242ac1c0002row8_col0{
#             background-color:  #9ece66;
#             color:  #000000;
#         }#T_3b4a0f00_1aa5_11eb_a715_0242ac1c0002row9_col0{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_3b4a0f00_1aa5_11eb_a715_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Fare</th>    </tr>    <tr>        <th class="index_name level0" >Fare_Range</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3b4a0f00_1aa5_11eb_a715_0242ac1c0002level0_row0" class="row_heading level0 row0" >(-0.001, 7.55]</th>
#                         <td id="T_3b4a0f00_1aa5_11eb_a715_0242ac1c0002row0_col0" class="data row0 col0" >5.928717</td>
#             </tr>
#             <tr>
#                         <th id="T_3b4a0f00_1aa5_11eb_a715_0242ac1c0002level0_row1" class="row_heading level0 row1" >(7.55, 7.854]</th>
#                         <td id="T_3b4a0f00_1aa5_11eb_a715_0242ac1c0002row1_col0" class="data row1 col0" >7.768490</td>
#             </tr>
#             <tr>
#                         <th id="T_3b4a0f00_1aa5_11eb_a715_0242ac1c0002level0_row2" class="row_heading level0 row2" >(7.854, 8.05]</th>
#                         <td id="T_3b4a0f00_1aa5_11eb_a715_0242ac1c0002row2_col0" class="data row2 col0" >7.963669</td>
#             </tr>
#             <tr>
#                         <th id="T_3b4a0f00_1aa5_11eb_a715_0242ac1c0002level0_row3" class="row_heading level0 row3" >(8.05, 10.5]</th>
#                         <td id="T_3b4a0f00_1aa5_11eb_a715_0242ac1c0002row3_col0" class="data row3 col0" >9.521367</td>
#             </tr>
#             <tr>
#                         <th id="T_3b4a0f00_1aa5_11eb_a715_0242ac1c0002level0_row4" class="row_heading level0 row4" >(10.5, 14.454]</th>
#                         <td id="T_3b4a0f00_1aa5_11eb_a715_0242ac1c0002row4_col0" class="data row4 col0" >12.940231</td>
#             </tr>
#             <tr>
#                         <th id="T_3b4a0f00_1aa5_11eb_a715_0242ac1c0002level0_row5" class="row_heading level0 row5" >(14.454, 21.679]</th>
#                         <td id="T_3b4a0f00_1aa5_11eb_a715_0242ac1c0002row5_col0" class="data row5 col0" >17.386408</td>
#             </tr>
#             <tr>
#                         <th id="T_3b4a0f00_1aa5_11eb_a715_0242ac1c0002level0_row6" class="row_heading level0 row6" >(21.679, 27.0]</th>
#                         <td id="T_3b4a0f00_1aa5_11eb_a715_0242ac1c0002row6_col0" class="data row6 col0" >25.487501</td>
#             </tr>
#             <tr>
#                         <th id="T_3b4a0f00_1aa5_11eb_a715_0242ac1c0002level0_row7" class="row_heading level0 row7" >(27.0, 39.688]</th>
#                         <td id="T_3b4a0f00_1aa5_11eb_a715_0242ac1c0002row7_col0" class="data row7 col0" >32.282186</td>
#             </tr>
#             <tr>
#                         <th id="T_3b4a0f00_1aa5_11eb_a715_0242ac1c0002level0_row8" class="row_heading level0 row8" >(39.688, 77.958]</th>
#                         <td id="T_3b4a0f00_1aa5_11eb_a715_0242ac1c0002row8_col0" class="data row8 col0" >59.444572</td>
#             </tr>
#             <tr>
#                         <th id="T_3b4a0f00_1aa5_11eb_a715_0242ac1c0002level0_row9" class="row_heading level0 row9" >(77.958, 512.329]</th>
#                         <td id="T_3b4a0f00_1aa5_11eb_a715_0242ac1c0002row9_col0" class="data row9 col0" >146.807086</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# - Fare 그룹 : Fgroup으로 컬렴명 지정
#       0 이하 -> 0
#       7.125 이하 -> 5.0
#       7.9 이하 -> 7.5
#       8.03 이하 -> 8.0
#       10.5 이하 -> 9.5
#       23 이하 -> 16.0
#       27.8 이하 -> 25.5
#       51 이하 -> 38
#       73.5 이하 -> 62
#       73.5 초과 -> 100

# %%
temp['Fgroup'] = 0

temp.loc[temp['Fare'] <= 0,'Fgroup'] = 0
temp.loc[(temp['Fare'] > 0) & (temp['Fare'] <= 7.125), 'Fgroup'] = 1
temp.loc[(temp['Fare'] > 7.125) & (temp['Fare'] <= 7.9), 'Fgroup'] = 2
temp.loc[(temp['Fare'] > 7.9) & (temp['Fare'] <= 8.03), 'Fgroup'] = 3
temp.loc[(temp['Fare'] > 8.03) & (temp['Fare'] < 10.5), 'Fgroup'] = 4
temp.loc[(temp['Fare'] >= 10.5) & (temp['Fare'] < 23.0), 'Fgroup'] = 5
temp.loc[(temp['Fare'] >= 23.0) & (temp['Fare'] <= 27.8), 'Fgroup'] = 6
temp.loc[(temp['Fare'] > 27.8) & (temp['Fare'] <= 51.0), 'Fgroup'] = 7
temp.loc[(temp['Fare'] > 51.0) & (temp['Fare'] <= 73.5), 'Fgroup'] = 8
temp.loc[temp['Fare'] > 73.5, 'Fgroup'] = 9

temp.head()
# Out:
#    PassengerId  Survived  Pclass  ... NumTicket        Fare_Range  Fgroup
# 0            1       0.0       3  ...         0    (-0.001, 7.55]       2
# 1            2       1.0       1  ...         1  (39.688, 77.958]       8
# 2            3       1.0       3  ...         2     (7.854, 8.05]       3
# 3            4       1.0       1  ...        -1  (39.688, 77.958]       8
# 4            5       0.0       3  ...        -1     (7.854, 8.05]       4
#
# [5 rows x 25 columns]

# %% [markdown]
# ### "Cabin" 분석
# - cabin 위치에 따라 생존여부의 차이가 있는지 확인

# %%
temp.Cabin.value_counts().head(10)
# Out:
# C23 C25 C27        6
# B57 B59 B63 B66    5
# G6                 5
# F4                 4
# C22 C26            4
# B96 B98            4
# D                  4
# F33                4
# F2                 4
# C78                4
# Name: Cabin, dtype: int64

# %%
temp.Cabin.isnull().sum()
# Out:
# 1014

# %% [markdown]
# - 결측치가 많은 것을 확인
#   - Cabin에 결측치가 많으므로 다른 분류로 진행
#   - 기존 것은 이니셜로 분류
#     - Pclass와 연관있을 것으로 추측, Pcalss별 결측치를 각각 X, Y, Z 부여

# %%
temp['Inicab'] = 0
temp['Inicab'] = temp['Cabin'].str.extract('^([A-Za-z]+)')
temp.loc[((temp['Cabin'].isnull()) & (temp['Pclass'].values == 1)), 'Inicab'] = 'X'
temp.loc[((temp['Cabin'].isnull()) & (temp['Pclass'].values == 2)), 'Inicab'] = 'Y'
temp.loc[((temp['Cabin'].isnull()) & (temp['Pclass'].values == 3)), 'Inicab'] = 'Z'
    
temp.head()
# Out:
#    PassengerId  Survived  Pclass  ...        Fare_Range Fgroup  Inicab
# 0            1       0.0       3  ...    (-0.001, 7.55]      2       Z
# 1            2       1.0       1  ...  (39.688, 77.958]      8       C
# 2            3       1.0       3  ...     (7.854, 8.05]      3       Z
# 3            4       1.0       1  ...  (39.688, 77.958]      8       C
# 4            5       0.0       3  ...     (7.854, 8.05]      4       Z
#
# [5 rows x 26 columns]

# %%
temp['Inicab'] = temp['Inicab'].factorize()[0]
    
temp[11:20]
# Out:
#     PassengerId  Survived  Pclass  ...        Fare_Range Fgroup  Inicab
# 11           12       1.0       1  ...    (21.679, 27.0]      6       1
# 12           13       0.0       3  ...     (7.854, 8.05]      4       0
# 13           14       0.0       3  ...    (27.0, 39.688]      7       0
# 14           15       0.0       3  ...     (7.55, 7.854]      2       0
# 15           16       1.0       2  ...  (14.454, 21.679]      5       3
# 16           17       0.0       3  ...    (27.0, 39.688]      7       0
# 17           18       1.0       2  ...    (10.5, 14.454]      5       3
# 18           19       0.0       3  ...  (14.454, 21.679]      5       0
# 19           20       1.0       3  ...    (-0.001, 7.55]      2       0
#
# [9 rows x 26 columns]

# %% [markdown]
# ### "Embarked" 분석
# - 승선 장소 별 생존 확률을 확인하고자 함

# %%
pd.crosstab([temp.Embarked, temp.Pclass], [temp.Sex, temp.Survived], margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_542d1a48_1aa6_11eb_a715_0242ac1c0002row0_col0,#T_542d1a48_1aa6_11eb_a715_0242ac1c0002row2_col3{
#             background-color:  #f2f866;
#             color:  #000000;
#         }#T_542d1a48_1aa6_11eb_a715_0242ac1c0002row0_col1{
#             background-color:  #d6eb66;
#             color:  #000000;
#         }#T_542d1a48_1aa6_11eb_a715_0242ac1c0002row0_col2,#T_542d1a48_1aa6_11eb_a715_0242ac1c0002row1_col0{
#             background-color:  #fcfe66;
#             color:  #000000;
#         }#T_542d1a48_1aa6_11eb_a715_0242ac1c0002row0_col3,#T_542d1a48_1aa6_11eb_a715_0242ac1c0002row7_col5{
#             background-color:  #d1e866;
#             color:  #000000;
#         }#T_542d1a48_1aa6_11eb_a715_0242ac1c0002row0_col4,#T_542d1a48_1aa6_11eb_a715_0242ac1c0002row1_col2,#T_542d1a48_1aa6_11eb_a715_0242ac1c0002row1_col4,#T_542d1a48_1aa6_11eb_a715_0242ac1c0002row3_col0,#T_542d1a48_1aa6_11eb_a715_0242ac1c0002row3_col1,#T_542d1a48_1aa6_11eb_a715_0242ac1c0002row3_col2,#T_542d1a48_1aa6_11eb_a715_0242ac1c0002row3_col3,#T_542d1a48_1aa6_11eb_a715_0242ac1c0002row3_col4,#T_542d1a48_1aa6_11eb_a715_0242ac1c0002row3_col5,#T_542d1a48_1aa6_11eb_a715_0242ac1c0002row4_col0,#T_542d1a48_1aa6_11eb_a715_0242ac1c0002row4_col1,#T_542d1a48_1aa6_11eb_a715_0242ac1c0002row4_col2,#T_542d1a48_1aa6_11eb_a715_0242ac1c0002row4_col4,#T_542d1a48_1aa6_11eb_a715_0242ac1c0002row4_col5,#T_542d1a48_1aa6_11eb_a715_0242ac1c0002row5_col4,#T_542d1a48_1aa6_11eb_a715_0242ac1c0002row8_col4{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_542d1a48_1aa6_11eb_a715_0242ac1c0002row0_col5{
#             background-color:  #e8f466;
#             color:  #000000;
#         }#T_542d1a48_1aa6_11eb_a715_0242ac1c0002row1_col1,#T_542d1a48_1aa6_11eb_a715_0242ac1c0002row1_col5{
#             background-color:  #fbfd66;
#             color:  #000000;
#         }#T_542d1a48_1aa6_11eb_a715_0242ac1c0002row1_col3,#T_542d1a48_1aa6_11eb_a715_0242ac1c0002row6_col2{
#             background-color:  #f9fc66;
#             color:  #000000;
#         }#T_542d1a48_1aa6_11eb_a715_0242ac1c0002row2_col0{
#             background-color:  #eef666;
#             color:  #000000;
#         }#T_542d1a48_1aa6_11eb_a715_0242ac1c0002row2_col1{
#             background-color:  #e9f466;
#             color:  #000000;
#         }#T_542d1a48_1aa6_11eb_a715_0242ac1c0002row2_col2,#T_542d1a48_1aa6_11eb_a715_0242ac1c0002row5_col3{
#             background-color:  #e6f266;
#             color:  #000000;
#         }#T_542d1a48_1aa6_11eb_a715_0242ac1c0002row2_col4,#T_542d1a48_1aa6_11eb_a715_0242ac1c0002row7_col4{
#             background-color:  #92c866;
#             color:  #000000;
#         }#T_542d1a48_1aa6_11eb_a715_0242ac1c0002row2_col5,#T_542d1a48_1aa6_11eb_a715_0242ac1c0002row7_col2{
#             background-color:  #edf666;
#             color:  #000000;
#         }#T_542d1a48_1aa6_11eb_a715_0242ac1c0002row4_col3{
#             background-color:  #fefe66;
#             color:  #000000;
#         }#T_542d1a48_1aa6_11eb_a715_0242ac1c0002row5_col0{
#             background-color:  #ecf666;
#             color:  #000000;
#         }#T_542d1a48_1aa6_11eb_a715_0242ac1c0002row5_col1{
#             background-color:  #f8fc66;
#             color:  #000000;
#         }#T_542d1a48_1aa6_11eb_a715_0242ac1c0002row5_col2{
#             background-color:  #e3f166;
#             color:  #000000;
#         }#T_542d1a48_1aa6_11eb_a715_0242ac1c0002row5_col5{
#             background-color:  #ebf566;
#             color:  #000000;
#         }#T_542d1a48_1aa6_11eb_a715_0242ac1c0002row6_col0{
#             background-color:  #e4f266;
#             color:  #000000;
#         }#T_542d1a48_1aa6_11eb_a715_0242ac1c0002row6_col1{
#             background-color:  #bdde66;
#             color:  #000000;
#         }#T_542d1a48_1aa6_11eb_a715_0242ac1c0002row6_col3{
#             background-color:  #cde666;
#             color:  #000000;
#         }#T_542d1a48_1aa6_11eb_a715_0242ac1c0002row6_col4,#T_542d1a48_1aa6_11eb_a715_0242ac1c0002row6_col5{
#             background-color:  #dbed66;
#             color:  #000000;
#         }#T_542d1a48_1aa6_11eb_a715_0242ac1c0002row7_col0{
#             background-color:  #d3e966;
#             color:  #000000;
#         }#T_542d1a48_1aa6_11eb_a715_0242ac1c0002row7_col1{
#             background-color:  #e2f066;
#             color:  #000000;
#         }#T_542d1a48_1aa6_11eb_a715_0242ac1c0002row7_col3{
#             background-color:  #bcde66;
#             color:  #000000;
#         }#T_542d1a48_1aa6_11eb_a715_0242ac1c0002row8_col0{
#             background-color:  #81c066;
#             color:  #000000;
#         }#T_542d1a48_1aa6_11eb_a715_0242ac1c0002row8_col1{
#             background-color:  #acd666;
#             color:  #000000;
#         }#T_542d1a48_1aa6_11eb_a715_0242ac1c0002row8_col2{
#             background-color:  #52a866;
#             color:  #000000;
#         }#T_542d1a48_1aa6_11eb_a715_0242ac1c0002row8_col3{
#             background-color:  #dcee66;
#             color:  #000000;
#         }#T_542d1a48_1aa6_11eb_a715_0242ac1c0002row8_col5{
#             background-color:  #9acc66;
#             color:  #000000;
#         }#T_542d1a48_1aa6_11eb_a715_0242ac1c0002row9_col0,#T_542d1a48_1aa6_11eb_a715_0242ac1c0002row9_col1,#T_542d1a48_1aa6_11eb_a715_0242ac1c0002row9_col2,#T_542d1a48_1aa6_11eb_a715_0242ac1c0002row9_col3,#T_542d1a48_1aa6_11eb_a715_0242ac1c0002row9_col4,#T_542d1a48_1aa6_11eb_a715_0242ac1c0002row9_col5{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_542d1a48_1aa6_11eb_a715_0242ac1c0002" ><thead>    <tr>        <th class="blank" ></th>        <th class="index_name level0" >Sex</th>        <th class="col_heading level0 col0" colspan=2>1</th>        <th class="col_heading level0 col2" colspan=2>2</th>        <th class="col_heading level0 col4" >3</th>        <th class="col_heading level0 col5" >All</th>    </tr>    <tr>        <th class="blank" ></th>        <th class="index_name level1" >Survived</th>        <th class="col_heading level1 col0" >0.0</th>        <th class="col_heading level1 col1" >1.0</th>        <th class="col_heading level1 col2" >0.0</th>        <th class="col_heading level1 col3" >1.0</th>        <th class="col_heading level1 col4" >1.0</th>        <th class="col_heading level1 col5" ></th>    </tr>    <tr>        <th class="index_name level0" >Embarked</th>        <th class="index_name level1" >Pclass</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_542d1a48_1aa6_11eb_a715_0242ac1c0002level0_row0" class="row_heading level0 row0" rowspan=3>C</th>
#                         <th id="T_542d1a48_1aa6_11eb_a715_0242ac1c0002level1_row0" class="row_heading level1 row0" >1</th>
#                         <td id="T_542d1a48_1aa6_11eb_a715_0242ac1c0002row0_col0" class="data row0 col0" >25</td>
#                         <td id="T_542d1a48_1aa6_11eb_a715_0242ac1c0002row0_col1" class="data row0 col1" >17</td>
#                         <td id="T_542d1a48_1aa6_11eb_a715_0242ac1c0002row0_col2" class="data row0 col2" >1</td>
#                         <td id="T_542d1a48_1aa6_11eb_a715_0242ac1c0002row0_col3" class="data row0 col3" >42</td>
#                         <td id="T_542d1a48_1aa6_11eb_a715_0242ac1c0002row0_col4" class="data row0 col4" >0</td>
#                         <td id="T_542d1a48_1aa6_11eb_a715_0242ac1c0002row0_col5" class="data row0 col5" >85</td>
#             </tr>
#             <tr>
#                                 <th id="T_542d1a48_1aa6_11eb_a715_0242ac1c0002level1_row1" class="row_heading level1 row1" >2</th>
#                         <td id="T_542d1a48_1aa6_11eb_a715_0242ac1c0002row1_col0" class="data row1 col0" >8</td>
#                         <td id="T_542d1a48_1aa6_11eb_a715_0242ac1c0002row1_col1" class="data row1 col1" >2</td>
#                         <td id="T_542d1a48_1aa6_11eb_a715_0242ac1c0002row1_col2" class="data row1 col2" >0</td>

# %%
sns.factorplot('Embarked', 'Survived', data=temp)
fig = plt.gcf()
fig.set_size_inches(5, 3)
plt.show()

# %%
f,ax=plt.subplots(2,2,figsize=(10,7))
sns.countplot('Embarked', data=temp, ax=ax[0,0])
ax[0,0].set_title('No. Of Passengers Boarded')
sns.countplot('Embarked', hue='Sex', data=temp, ax=ax[0,1])
ax[0,1].set_title('Male-Female Split for Embarked')
sns.countplot('Embarked', hue='Survived', data=temp, ax=ax[1,0])
ax[1,0].set_title('Embarked vs Survived')
sns.countplot('Embarked', hue='Pclass', data=temp, ax=ax[1,1])
ax[1,1].set_title('Embarked vs Pclass')
plt.subplots_adjust(wspace=0.2,hspace=0.5)
plt.show()

# %% [markdown]
# - 포트 C의 생존 가능성은 0.55 정도로 가장 높음
#
# - 포트 S는 탑승객이 가장 많으며 생존률은 가장 낮음, 탑승객 대다수는 Pclass3
#
# - 포트 S는 대부분 부유층이 탑승한 항구이지만, 생존 가능성은 낮음
#   - 그럼에도 Pclass3의 승객도 많았음
#
# - 포트 Q는 승객의 약 95%가 Pclass3

# %% [markdown]
# -  Embarked의 결측치 확인

# %%
temp.loc[(temp.Embarked.isnull())]
# Out:
#      PassengerId  Survived  Pclass  ...         Fare_Range Fgroup  Inicab
# 61            62       1.0       1  ...  (77.958, 512.329]      9       8
# 829          830       1.0       1  ...  (77.958, 512.329]      9       8
#
# [2 rows x 26 columns]

# %% [markdown]
# - 두 사람의 티켓 번호가 동일
#   - 추가로 있는지 확인

# %%
temp.loc[(temp.Ticket == '113572')]
# Out:
#      PassengerId  Survived  Pclass  ...         Fare_Range Fgroup  Inicab
# 61            62       1.0       1  ...  (77.958, 512.329]      9       8
# 829          830       1.0       1  ...  (77.958, 512.329]      9       8
#
# [2 rows x 26 columns]

# %% [markdown]
# - 비슷한 번호를 찾아 유추하고자 함

# %%
temp.sort_values(['Ticket'], ascending = True)[55:70]
# Out:
#       PassengerId  Survived  Pclass  ...         Fare_Range Fgroup  Inicab
# 54             55       0.0       1  ...   (39.688, 77.958]      8       8
# 351           352       0.0       1  ...     (27.0, 39.688]      7       1
# 252           253       0.0       1  ...     (21.679, 27.0]      6       1
# 829           830       1.0       1  ...  (77.958, 512.329]      9       8
# 61             62       1.0       1  ...  (77.958, 512.329]      9       8
# 802           803       1.0       1  ...  (77.958, 512.329]      9       8
# 390           391       1.0       1  ...  (77.958, 512.329]      9       8
# 435           436       1.0       1  ...  (77.958, 512.329]      9       8
# 763           764       1.0       1  ...  (77.958, 512.329]      9       8
# 185           186       0.0       1  ...   (39.688, 77.958]      7       6
# 1073         1074       NaN       1  ...                NaN      8       5
# 748           749       0.0       1  ...   (39.688, 77.958]      8       5
# 151           152       1.0       1  ...   (39.688, 77.958]      8       1
# 336           337       0.0       1  ...   (39.688, 77.958]      8       1
# 932           933       NaN       1  ...                NaN      6       5
#
# [15 rows x 26 columns]

# %% [markdown]
# - 앞뒤로 모두 S이고 Pclass도 모두 1인 것으로 보아 S일 가능성이 큼

# %%
temp.loc[(temp.Embarked.isnull()), 'Embarked'] = 'S'
temp.loc[(temp.Embarked.isnull())]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, Initial, NumInit, LastName, NumName, Gender, Age_Range, Agroup, Alone, Family, Initick, NumTicket, Fare_Range, Fgroup, Inicab]
# Index: []

# %%
temp['Embarked'] = temp['Embarked'].factorize()[0]
    
temp[11:20]
# Out:
#     PassengerId  Survived  Pclass  ...        Fare_Range Fgroup  Inicab
# 11           12       1.0       1  ...    (21.679, 27.0]      6       1
# 12           13       0.0       3  ...     (7.854, 8.05]      4       0
# 13           14       0.0       3  ...    (27.0, 39.688]      7       0
# 14           15       0.0       3  ...     (7.55, 7.854]      2       0
# 15           16       1.0       2  ...  (14.454, 21.679]      5       3
# 16           17       0.0       3  ...    (27.0, 39.688]      7       0
# 17           18       1.0       2  ...    (10.5, 14.454]      5       3
# 18           19       0.0       3  ...  (14.454, 21.679]      5       0
# 19           20       1.0       3  ...    (-0.001, 7.55]      2       0
#
# [9 rows x 26 columns]

# %% [markdown]
# ## Part 5 : Feature Engineering

# %% [markdown]
# - 문자를 수치화 하는 작업도 Feature Engineering의 일부
#   - Part 4과정에서 대부분 가공
